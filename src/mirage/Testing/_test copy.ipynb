# %% [markdown]
# ## TO DO

# %% [markdown]
# #### * Change all keys in YAML and inputs fro user to lower

# %%
import yaml
from mirage.src.mirage.processes import ProcessV1
from mirage.src.mirage.entities import EntityV1
from mirage.src.mirage.simulations.epidemics import gpe
import pprint
from mirage.configs.simulations.epidemics.epidemic_constants import *
import numpy as np
import matplotlib.pyplot as plt
import gc

# %%
file_path = "D:/IIT MANDI/KBG Coordinator/MIRAZ/Epidemic_2/NEW_ENGINE/epidemic_engine/mirage/configs/simulations/epidemics/countries/india.yaml"
with open(file_path, 'r') as file:
    ind_config = yaml.load(file, Loader=yaml.FullLoader)
print(ind_config)
# Out:
# {'name': 'India', 'gdp': 2875140000, 'health_resource_stockpile': 50000.0, 'sanitation_equipment_stockpile': 50000.0, 'human_welfare_resource': 10000.0, 'happiness_index': 1.0, 'procedure_resistance': 0.6, 'cleanliness_index': 0.7, 'disease_research_center': 0, 'vaccine_research_center': 0, 'vaccines_stock': [{'name': 'ABC', 'quantity': 20, 'gdp_cost_per_step': 1000, 'effectiveness': 0.4}, {'name': 'ACB', 'quantity': 30, 'gdp_cost_per_step': 1000, 'effectiveness': 0.22}, {'name': 'BAC', 'quantity': 10, 'gdp_cost_per_step': 1000, 'effectiveness': 0.95}, {'name': 'BCA', 'quantity': 12, 'gdp_cost_per_step': 1000, 'effectiveness': -0.2}, {'name': 'CAB', 'quantity': 23, 'gdp_cost_per_step': 1000, 'effectiveness': 0.5}, {'name': 'CBA', 'quantity': 10, 'gdp_cost_per_step': 1000, 'effectiveness': 0.1}], 'loci': [{'name': 'Maharashtra', 'B': 0.01, 'C': 0.01, 'E': 0.01, 'A': 0.01, 'Ds': 0.01, 'Di': 0.01, 'Dr': 0.01, 'lat': 19.7515, 'lon': 75.7139, 'susceptible': 112374333, 'infected': 100000, 'recovered': 200, 'dead': 0, 'area': 307713, 'quarantine_facilities': 2, 'general_hospitals': 10, 'vaccine_distribution_centers': 0, 'airports': [{'name': 'Chhatrapati Shivaji Maharaj International Airport', 'hub_tier': 1, 'effect': 1.0}, {'name': 'Pune International Airport', 'hub_tier': 2, 'effect': 1.0}], 'ports': [{'name': 'Mumbai Port', 'hub_tier': 1, 'effect': 1.0, 'b_val_increase': 0.0005}, {'name': 'Jawaharlal Nehru Port', 'hub_tier': 2, 'effect': 1.0, 'b_val_increase': 0.0003}, {'name': 'Goa Port', 'hub_tier': 3, 'effect': 1.0, 'b_val_increase': 0.0001}], 'economic_zones': [{'name': 'Mumbai SEZ', 'zone_tier': 1, 'effect': 1.0, 'b_val_increase': 5e-05}, {'name': 'Pune IT Park', 'zone_tier': 2, 'effect': 1.0, 'b_val_increase': 2e-05}], 'tourist_zones': [{'name': 'Gateway of India', 'zone_tier': 1, 'effect': 1.0, 'b_val_increase': 5e-05}, {'name': 'Elephanta Caves', 'zone_tier': 2, 'effect': 1.0, 'b_val_increase': 2e-05}]}, {'name': 'Delhi', 'B': 0.01, 'C': 0.01, 'E': 0.01, 'A': 0.01, 'Ds': 0.01, 'Di': 0.01, 'Dr': 0.01, 'lat': 28.7041, 'lon': 77.1025, 'susceptible': 16787941, 'infected': 100000, 'recovered': 20000, 'dead': 0, 'area': 1484, 'quarantine_facilities': 2, 'general_hospitals': 10, 'vaccine_distribution_centers': 0, 'airports': [{'name': 'Indira Gandhi International Airport', 'hub_tier': 1, 'effect': 1.0, 'b_val_increase': 0.0005}], 'ports': None, 'economic_zones': [{'name': 'Delhi SEZ', 'zone_tier': 1, 'effect': 1.0, 'b_val_increase': 5e-05}, {'name': 'Gurgaon Industrial Zone', 'zone_tier': 2, 'effect': 1.0, 'b_val_increase': 2e-05}], 'tourist_zones': [{'name': 'Qutub Minar', 'zone_tier': 1, 'effect': 1.0, 'b_val_increase': 5e-05}, {'name': 'Red Fort', 'zone_tier': 2, 'effect': 1.0, 'b_val_increase': 2e-05}]}, {'name': 'Uttar Pradesh', 'B': 0.01, 'C': 0.01, 'E': 0.01, 'A': 0.01, 'Ds': 0.01, 'Di': 0.01, 'Dr': 0.01, 'lat': 26.8467, 'lon': 80.9462, 'susceptible': 199812341, 'infected': 100000, 'recovered': 200, 'dead': 0, 'area': 243290, 'quarantine_facilities': 2, 'general_hospitals': 10, 'vaccine_distribution_centers': 0, 'airports': [{'name': 'Chaudhary Charan Singh International Airport', 'hub_tier': 1, 'effect': 1.0, 'b_val_increase': 0.0005}], 'ports': None, 'economic_zones': [{'name': 'Noida SEZ', 'zone_tier': 1, 'effect': 1.0, 'b_val_increase': 5e-05}], 'tourist_zones': [{'name': 'Taj Mahal', 'zone_tier': 1, 'effect': 1.0, 'b_val_increase': 5e-05}, {'name': 'Varanasi Spiritual Hub', 'zone_tier': 3, 'effect': 1.0, 'b_val_increase': 1e-05}]}, {'name': 'Rajasthan', 'B': 0.01, 'C': 0.01, 'E': 0.01, 'A': 0.01, 'Ds': 0.01, 'Di': 0.01, 'Dr': 0.01, 'lat': 27.0238, 'lon': 74.2179, 'susceptible': 68548437, 'infected': 100000, 'recovered': 200, 'dead': 0, 'area': 342239, 'quarantine_facilities': 2, 'general_hospitals': 10, 'vaccine_distribution_centers': 0, 'airports': [{'name': 'Jaipur International Airport', 'hub_tier': 1, 'effect': 1.0, 'b_val_increase': 0.0005}], 'ports': None, 'economic_zones': [{'name': 'Jaipur SEZ', 'zone_tier': 1 ...

# %%
ind = gpe.Country(**ind_config)
gc.collect()
# Out:
# 5503

# %%
type(gpe.Country)
# Out:
# pydantic._internal._model_construction.ModelMetaclass

# %%
type(EntityV1)
# Out:
# pydantic._internal._model_construction.ModelMetaclass

# %%
cls = gpe.Country

# %%
ind
# Out:
# Country(name='India', gdp=2875140000, health_resource_stockpile=50000.0, sanitation_equipment_stockpile=50000.0, human_welfare_resource=10000.0, happiness_index=1.0, procedure_resistance=0.6, cleanliness_index=0.7, disease_research_center=0, vaccine_research_center=0, vaccines_stock=[{'name': 'ABC', 'quantity': 20, 'gdp_cost_per_step': 1000, 'effectiveness': 0.4}, {'name': 'ACB', 'quantity': 30, 'gdp_cost_per_step': 1000, 'effectiveness': 0.22}, {'name': 'BAC', 'quantity': 10, 'gdp_cost_per_step': 1000, 'effectiveness': 0.95}, {'name': 'BCA', 'quantity': 12, 'gdp_cost_per_step': 1000, 'effectiveness': -0.2}, {'name': 'CAB', 'quantity': 23, 'gdp_cost_per_step': 1000, 'effectiveness': 0.5}, {'name': 'CBA', 'quantity': 10, 'gdp_cost_per_step': 1000, 'effectiveness': 0.1}], loci=[Locus(B=0.01, C=0.01, E=0.01, A=0.01, Ds=0.01, Di=0.01, Dr=0.01, lat=19.7515, lon=75.7139, name='Maharashtra', susceptible=112374333, infected=100000, recovered=200, dead=0, area=307713, quarantine_facilities=2, general_hospitals=10, vaccine_distribution_centers=0, airports=[{'name': 'Chhatrapati Shivaji Maharaj International Airport', 'hub_tier': 1, 'effect': 1.0}, {'name': 'Pune International Airport', 'hub_tier': 2, 'effect': 1.0}], ports=[{'name': 'Mumbai Port', 'hub_tier': 1, 'effect': 1.0, 'b_val_increase': 0.0005}, {'name': 'Jawaharlal Nehru Port', 'hub_tier': 2, 'effect': 1.0, 'b_val_increase': 0.0003}, {'name': 'Goa Port', 'hub_tier': 3, 'effect': 1.0, 'b_val_increase': 0.0001}], economic_zones=[{'name': 'Mumbai SEZ', 'zone_tier': 1, 'effect': 1.0, 'b_val_increase': 5e-05}, {'name': 'Pune IT Park', 'zone_tier': 2, 'effect': 1.0, 'b_val_increase': 2e-05}], tourist_zones=[{'name': 'Gateway of India', 'zone_tier': 1, 'effect': 1.0, 'b_val_increase': 5e-05}, {'name': 'Elephanta Caves', 'zone_tier': 2, 'effect': 1.0, 'b_val_increase': 2e-05}]), Locus(B=0.01, C=0.01, E=0.01, A=0.01, Ds=0.01, Di=0.01, Dr=0.01, lat=28.7041, lon=77.1025, name='Delhi', susceptible=16787941, infected=100000, recovered=20000, dead=0, area=1484, quarantine_facilities=2, general_hospitals=10, vaccine_distribution_centers=0, airports=[{'name': 'Indira Gandhi International Airport', 'hub_tier': 1, 'effect': 1.0, 'b_val_increase': 0.0005}], ports=None, economic_zones=[{'name': 'Delhi SEZ', 'zone_tier': 1, 'effect': 1.0, 'b_val_increase': 5e-05}, {'name': 'Gurgaon Industrial Zone', 'zone_tier': 2, 'effect': 1.0, 'b_val_increase': 2e-05}], tourist_zones=[{'name': 'Qutub Minar', 'zone_tier': 1, 'effect': 1.0, 'b_val_increase': 5e-05}, {'name': 'Red Fort', 'zone_tier': 2, 'effect': 1.0, 'b_val_increase': 2e-05}]), Locus(B=0.01, C=0.01, E=0.01, A=0.01, Ds=0.01, Di=0.01, Dr=0.01, lat=26.8467, lon=80.9462, name='Uttar Pradesh', susceptible=199812341, infected=100000, recovered=200, dead=0, area=243290, quarantine_facilities=2, general_hospitals=10, vaccine_distribution_centers=0, airports=[{'name': 'Chaudhary Charan Singh International Airport', 'hub_tier': 1, 'effect': 1.0, 'b_val_increase': 0.0005}], ports=None, economic_zones=[{'name': 'Noida SEZ', 'zone_tier': 1, 'effect': 1.0, 'b_val_increase': 5e-05}], tourist_zones=[{'name': 'Taj Mahal', 'zone_tier': 1, 'effect': 1.0, 'b_val_increase': 5e-05}, {'name': 'Varanasi Spiritual Hub', 'zone_tier': 3, 'effect': 1.0, 'b_val_increase': 1e-05}]), Locus(B=0.01, C=0.01, E=0.01, A=0.01, Ds=0.01, Di=0.01, Dr=0.01, lat=27.0238, lon=74.2179, name='Rajasthan', susceptible=68548437, infected=100000, recovered=200, dead=0, area=342239, quarantine_facilities=2, general_hospitals=10, vaccine_distribution_centers=0, airports=[{'name': 'Jaipur International Airport', 'hub_tier': 1, 'effect': 1.0, 'b_val_increase': 0.0005}], ports=None, economic_zones=[{'name': 'Jaipur SEZ', 'zone_tier': 1, 'effect': 1.0, 'b_val_increase': 5e-05}], tourist_zones=[{'name': 'Jaipur Historical Sites', 'zone_tier': 1, 'effect': 1.0, 'b_val_increase': 5e-05}, {'name': 'Udaipur Historical Sites', 'zone_tier': 2, 'effect': 1.0, 'b_val_increase': 2e-05}]), Locus(B=0.01, C=0.01,  ...

# %%
issubclass(gpe.Country, EntityV1)
# Out:
# True

# %%
val = lambda x: all(issubclass(dm, EntityV1) for dm in x)
val((gpe.Country, ))
# Out:
# True

# %% [markdown]
# ### Birth Process ( A Parameter )

# %%
class BirthProcess(ProcessV1):
    RANK = 0
    DOMAIN = (gpe.Country,)

    def __init__(
        self,
        id: str,
        entities,
        status: str,
        alpha,
        beta,
        gamma,
        max_birth_rate,
        economic_prosperity_THRESH,
    ):
        super().__init__(id, entities, status)
        self.alpha = alpha
        self.beta = beta
        self.gamma = gamma
        self.max_birth_rate = max_birth_rate
        self.economic_prosperity_THRESH = economic_prosperity_THRESH
        self.status = status
        self.id = id

    def while_dormant(self, step: int):
        pass

    def while_alive(self, step: int):
        birth_rates = {}
        for country in self.entities:

            economic_prosperity = self.entities[country].human_welfare_resource

            for i, locus in enumerate(self.entities[country].loci):

                living_population_contribution = (
                    self.alpha * (locus.susceptible)
                    + self.beta * (locus.recovered)
                    + self.gamma * (locus.infected)
                ) / max_living_population

                if (economic_prosperity < self.economic_prosperity_THRESH) and (
                    economic_prosperity > base_birth_rate
                ):
                    birth_rate = (
                        (
                            self.alpha * (locus.susceptible)
                            + self.beta * (locus.recovered)
                            + self.gamma * (locus.infected)
                        )
                        * economic_prosperity
                        / max_living_population
                    )
                    if locus.A + birth_rate <= self.max_birth_rate:
                        locus.A += birth_rate
                    else:
                        locus.A = self.max_birth_rate

                elif economic_prosperity >= self.economic_prosperity_THRESH:
                    economic_prosperity_use = living_population_contribution * (
                        1 - (min_human_welfare_resource / economic_prosperity)
                    )
                    birth_rate = (
                        (2 / (1 + np.exp(-economic_prosperity_use))) - 1
                    ) * self.max_birth_rate

                    if locus.A + birth_rate <= self.max_birth_rate:
                        self.entities[country].loci[i].A += birth_rate
                    else:
                        locus.A = self.max_birth_rate
                elif economic_prosperity <= base_birth_rate:
                    birth_rate = base_birth_rate
                    if locus.A + birth_rate <= max_birth_rate:
                        locus.A += birth_rate
                    else:
                        locus.A = max_birth_rate
                birth_rates[
                    "BirthRate" + "_" + str(locus.name) + "_" + str(country)
                ] = locus.A

        return birth_rates

    def run(self, step: int):
        return self.while_alive(step)

# %%
birth_process = BirthProcess('BirthProcess', {"india": ind}, "ALIVE", 
                            alpha = 0.4, 
                            beta = 0.1, 
                            gamma = 0.6, 
                            max_birth_rate = 0.35, 
                            economic_prosperity_THRESH = 0.1 )

k = []
for i in range (10):
    k.append(birth_process.run(i))
    ind.sync()
k
# Out:
# [{'BirthRate_Maharashtra_india': 0.01,
#   'BirthRate_Delhi_india': 0.01,
#   'BirthRate_Uttar Pradesh_india': 0.01,
#   'BirthRate_Rajasthan_india': 0.01,
#   'BirthRate_Kerala_india': 0.01,
#   'BirthRate_West Bengal_india': 0.01,
#   'BirthRate_Gujarat_india': 0.01},
#  {'BirthRate_Maharashtra_india': 0.010786881684536523,
#   'BirthRate_Delhi_india': 0.010118481981887176,
#   'BirthRate_Uttar Pradesh_india': 0.011398329560220202,
#   'BirthRate_Rajasthan_india': 0.010480408217891592,
#   'BirthRate_Kerala_india': 0.010234657849063047,
#   'BirthRate_West Bengal_india': 0.010639342460722925,
#   'BirthRate_Gujarat_india': 0.010423707005670505},
#  {'BirthRate_Maharashtra_india': 0.011573763369073045,
#   'BirthRate_Delhi_india': 0.010236963963774352,
#   'BirthRate_Uttar Pradesh_india': 0.012796659120440404,
#   'BirthRate_Rajasthan_india': 0.010960816435783184,
#   'BirthRate_Kerala_india': 0.010469315698126093,
#   'BirthRate_West Bengal_india': 0.011278684921445849,
#   'BirthRate_Gujarat_india': 0.01084741401134101},
#  {'BirthRate_Maharashtra_india': 0.012360645053609568,
#   'BirthRate_Delhi_india': 0.010355445945661528,
#   'BirthRate_Uttar Pradesh_india': 0.014194988680660606,
#   'BirthRate_Rajasthan_india': 0.011441224653674776,
#   'BirthRate_Kerala_india': 0.01070397354718914,
#   'BirthRate_West Bengal_india': 0.011918027382168773,
#   'BirthRate_Gujarat_india': 0.011271121017011514},
#  {'BirthRate_Maharashtra_india': 0.01314752673814609,
#   'BirthRate_Delhi_india': 0.010473927927548704,
#   'BirthRate_Uttar Pradesh_india': 0.015593318240880808,
#   'BirthRate_Rajasthan_india': 0.011921632871566367,
#   'BirthRate_Kerala_india': 0.010938631396252186,
#   'BirthRate_West Bengal_india': 0.012557369842891698,
#   'BirthRate_Gujarat_india': 0.011694828022682019},
#  {'BirthRate_Maharashtra_india': 0.013934408422682613,
#   'BirthRate_Delhi_india': 0.01059240990943588,
#   'BirthRate_Uttar Pradesh_india': 0.01699164780110101,
#   'BirthRate_Rajasthan_india': 0.01240204108945796,
#   'BirthRate_Kerala_india': 0.011173289245315233,
#   'BirthRate_West Bengal_india': 0.013196712303614622,
#   'BirthRate_Gujarat_india': 0.012118535028352523},
#  {'BirthRate_Maharashtra_india': 0.014721290107219136,
#   'BirthRate_Delhi_india': 0.010710891891323055,
#   'BirthRate_Uttar Pradesh_india': 0.01838997736132121,
#   'BirthRate_Rajasthan_india': 0.012882449307349551,
#   'BirthRate_Kerala_india': 0.01140794709437828,
#   'BirthRate_West Bengal_india': 0.013836054764337547,
#   'BirthRate_Gujarat_india': 0.012542242034023028},
#  {'BirthRate_Maharashtra_india': 0.015508171791755659,
#   'BirthRate_Delhi_india': 0.010829373873210231,
#   'BirthRate_Uttar Pradesh_india': 0.01978830692154141,
#   'BirthRate_Rajasthan_india': 0.013362857525241143,
#   'BirthRate_Kerala_india': 0.011642604943441326,
#   'BirthRate_West Bengal_india': 0.014475397225060471,
#   'BirthRate_Gujarat_india': 0.012965949039693532},
#  {'BirthRate_Maharashtra_india': 0.01629505347629218,
#   'BirthRate_Delhi_india': 0.010947855855097407,
#   'BirthRate_Uttar Pradesh_india': 0.02118663648176161,
#   'BirthRate_Rajasthan_india': 0.013843265743132735,
#   'BirthRate_Kerala_india': 0.011877262792504372,
#   'BirthRate_West Bengal_india': 0.015114739685783396,
#   'BirthRate_Gujarat_india': 0.013389656045364037},
#  {'BirthRate_Maharashtra_india': 0.0170819351608287,
#   'BirthRate_Delhi_india': 0.011066337836984583,
#   'BirthRate_Uttar Pradesh_india': 0.022584966041981812,
#   'BirthRate_Rajasthan_india': 0.014323673961024326,
#   'BirthRate_Kerala_india': 0.012111920641567419,
#   'BirthRate_West Bengal_india': 0.01575408214650632,
#   'BirthRate_Gujarat_india': 0.013813363051034542}]

# %% [markdown]
# ### **B PARMETER**

# %% [markdown]
# ### MASK Implementation  (Reduce Vaue)

# %%
class MaskImplementationProcess(ProcessV1):
    RANK = 1
    DOMAIN = (gpe.Country,)

    def __init__(
        self,
        id: str,
        entities,
        status: str,
        state,
        health_resource_cost,
        sanitation_equipment_cost,
        main_scale,
    ):
        super().__init__(id, entities, status)
        self.health_resource_cost = health_resource_cost
        self.sanitation_equipment_cost = sanitation_equipment_cost
        self.state = state
        self.id = id
        self.main_scale = main_scale

    def while_dormant(self, step: int):
        pass

    def while_alive(self, step: int):
        for country in self.entities:
            health_resource = self.entities[country].health_resource_stockpile
            sanitation_equipment = self.entities[country].sanitation_equipment_stockpile

            for locus in self.entities[country].loci:
                if locus.name == self.state:
                    if (
                        health_resource >= self.health_resource_cost
                        and sanitation_equipment >= self.sanitation_equipment_cost
                    ):
                        if (
                            self.entities[country].health_resource_stockpile
                            - self.health_resource_cost
                            <= 0
                        ):
                            self.entities[country].health_resource_stockpile = 0
                        else:
                            self.entities[
                                country
                            ].health_resource_stockpile -= self.health_resource_cost
                        if (
                            self.entities[country].sanitation_equipment_stockpile
                            - self.sanitation_equipment_cost
                            <= 0
                        ):
                            self.entities[country].sanitation_equipment_stockpile = 0
                        else:
                            self.entities[
                                country
                            ].sanitation_equipment_stockpile -= (
                                self.sanitation_equipment_cost
                            )
                        if (
                            locus.B
                            - (
                                locus.B
                                * self.main_scale
                                * (locus.infected + locus.susceptible)
                                / (5e9)
                            )
                            >= 0
                        ):
                            locus.B -= (
                                locus.B
                                * self.main_scale
                                * (locus.infected + locus.susceptible)
                                / (5e9)
                            )
                            # print("in")
                        else:
                            locus.B -= 0
                    else:
                        # print(f"Insufficient resources for mask implementation {sanitation_equipment} sanitation equipment and {health_resource} health resources left in the stockpile.")

                        locus.B -= 0
                    print(locus.B)
                else:
                    pass
        return {
            "MaskImplementationProcess"
            + "_"
            + str(locus.name)
            + "_"
            + str(country): locus.B
            for locus in self.entities[country].loci
        }

    def run(self, step: int):
        return self.while_alive(step)

# %%
mask_implementaton_process = MaskImplementationProcess(
    "MaskImplementationProcess",
    {"india": ind},
    "ALIVE",
    state="Delhi",
    health_resource_cost=0.1,
    sanitation_equipment_cost=0.1,
    main_scale=0.1,
)

k = []
for i in range(10):
    k.append(mask_implementaton_process.run(i))
    ind.sync()

k
# Out:
# 0.01
# 0.0099966224118
# 0.009993245964410206
# 0.009989870657445298
# 0.009986496490520086
# 0.009983123463249513
# 0.009979751575248653
# 0.009976380826132704
# 0.009973011215516999
# 0.009969642743017
# [{'MaskImplementationProcess_Maharashtra_india': 0.01,
#   'MaskImplementationProcess_Delhi_india': 0.01,
#   'MaskImplementationProcess_Uttar Pradesh_india': 0.01,
#   'MaskImplementationProcess_Rajasthan_india': 0.01,
#   'MaskImplementationProcess_Kerala_india': 0.01,
#   'MaskImplementationProcess_West Bengal_india': 0.01,
#   'MaskImplementationProcess_Gujarat_india': 0.01},
#  {'MaskImplementationProcess_Maharashtra_india': 0.01,
#   'MaskImplementationProcess_Delhi_india': 0.0099966224118,
#   'MaskImplementationProcess_Uttar Pradesh_india': 0.01,
#   'MaskImplementationProcess_Rajasthan_india': 0.01,
#   'MaskImplementationProcess_Kerala_india': 0.01,
#   'MaskImplementationProcess_West Bengal_india': 0.01,
#   'MaskImplementationProcess_Gujarat_india': 0.01},
#  {'MaskImplementationProcess_Maharashtra_india': 0.01,
#   'MaskImplementationProcess_Delhi_india': 0.009993245964410206,
#   'MaskImplementationProcess_Uttar Pradesh_india': 0.01,
#   'MaskImplementationProcess_Rajasthan_india': 0.01,
#   'MaskImplementationProcess_Kerala_india': 0.01,
#   'MaskImplementationProcess_West Bengal_india': 0.01,
#   'MaskImplementationProcess_Gujarat_india': 0.01},
#  {'MaskImplementationProcess_Maharashtra_india': 0.01,
#   'MaskImplementationProcess_Delhi_india': 0.009989870657445298,
#   'MaskImplementationProcess_Uttar Pradesh_india': 0.01,
#   'MaskImplementationProcess_Rajasthan_india': 0.01,
#   'MaskImplementationProcess_Kerala_india': 0.01,
#   'MaskImplementationProcess_West Bengal_india': 0.01,
#   'MaskImplementationProcess_Gujarat_india': 0.01},
#  {'MaskImplementationProcess_Maharashtra_india': 0.01,
#   'MaskImplementationProcess_Delhi_india': 0.009986496490520086,
#   'MaskImplementationProcess_Uttar Pradesh_india': 0.01,
#   'MaskImplementationProcess_Rajasthan_india': 0.01,
#   'MaskImplementationProcess_Kerala_india': 0.01,
#   'MaskImplementationProcess_West Bengal_india': 0.01,
#   'MaskImplementationProcess_Gujarat_india': 0.01},
#  {'MaskImplementationProcess_Maharashtra_india': 0.01,
#   'MaskImplementationProcess_Delhi_india': 0.009983123463249513,
#   'MaskImplementationProcess_Uttar Pradesh_india': 0.01,
#   'MaskImplementationProcess_Rajasthan_india': 0.01,
#   'MaskImplementationProcess_Kerala_india': 0.01,
#   'MaskImplementationProcess_West Bengal_india': 0.01,
#   'MaskImplementationProcess_Gujarat_india': 0.01},
#  {'MaskImplementationProcess_Maharashtra_india': 0.01,
#   'MaskImplementationProcess_Delhi_india': 0.009979751575248653,
#   'MaskImplementationProcess_Uttar Pradesh_india': 0.01,
#   'MaskImplementationProcess_Rajasthan_india': 0.01,
#   'MaskImplementationProcess_Kerala_india': 0.01,
#   'MaskImplementationProcess_West Bengal_india': 0.01,
#   'MaskImplementationProcess_Gujarat_india': 0.01},
#  {'MaskImplementationProcess_Maharashtra_india': 0.01,
#   'MaskImplementationProcess_Delhi_india': 0.009976380826132704,
#   'MaskImplementationProcess_Uttar Pradesh_india': 0.01,
#   'MaskImplementationProcess_Rajasthan_india': 0.01,
#   'MaskImplementationProcess_Kerala_india': 0.01,
#   'MaskImplementationProcess_West Bengal_india': 0.01,
#   'MaskImplementationProcess_Gujarat_india': 0.01},
#  {'MaskImplementationProcess_Maharashtra_india': 0.01,
#   'MaskImplementationProcess_Delhi_india': 0.009973011215516999,
#   'MaskImplementationProcess_Uttar Pradesh_india': 0.01,
#   'MaskImplementationProcess_Rajasthan_india': 0.01,
#   'MaskImplementationProcess_Kerala_india': 0.01,
#   'MaskImplementationProcess_West Bengal_india': 0.01,
#   'MaskImplementationProcess_Gujarat_india': 0.01},
#  {'MaskImplementationProcess_Maharashtra_india': 0.01,
#   'MaskImplementationProcess_Delhi_india': 0.009969642743017,
#   'MaskImplementationProcess_Uttar Pradesh_india': 0.01,
#   'MaskImplementationProcess_Rajasthan_india': 0.01,
#   'MaskImplementationProcess_Kerala_india': 0.01,
#   'MaskImplementationProcess_West Bengal_india': 0.01,
#   'MaskImplementationProcess_Gujarat_india': 0.01}]

# %% [markdown]
# ### AID KIT Implementation  (Reduce Vaue)

# %%
# Make AidKitImplementationProcess class similar to the above processes structure
class AidKitImplementationProcess(ProcessV1):
    RANK = 1
    DOMAIN = (gpe.Country,)

    def __init__(
        self,
        id: str,
        entities,
        status: str,
        state,
        healthcare_resource_cost,
        main_scale,
    ):
        super().__init__(id, entities, status)
        self.state = state
        self.healthcare_resource_cost = healthcare_resource_cost
        self.main_scale = main_scale
        self.status = status

    def while_dormant(self, step: int):
        pass

    def while_alive(self, step: int):
        for country in self.entities:
            sanitation_equipment = self.entities[country].health_resource_stockpile

            for locus in self.entities[country].loci:
                if locus.name == self.state:
                    if sanitation_equipment >= self.healthcare_resource_cost:
                        if (
                            self.entities[country].health_resource_stockpile
                            - self.healthcare_resource_cost
                            <= 0
                        ):
                            self.entities[country].sanitation_equipment_stockpile = 0
                        else:
                            self.entities[
                                country
                            ].health_resource_stockpile -= self.healthcare_resource_cost

                        if (
                            locus.B
                            - (
                                locus.B
                                * self.main_scale
                                * (locus.infected + locus.susceptible)
                                / (5e9)
                            )
                            >= 0
                        ):
                            locus.B -= (
                                locus.B
                                * self.main_scale
                                * (locus.infected + locus.susceptible)
                                / (5e9)
                            )
                        else:
                            locus.B -= 0
                    else:
                        locus.B -= 0

        return {
            "AidKitImplementationProcess"
            + "_"
            + str(locus.name)
            + "_"
            + str(country): locus.B
            for locus in self.entities[country].loci
        }

    def run(self, step: int):
        return self.while_alive(step)

# %%
Aid_kit_process = AidKitImplementationProcess(
    "AidKitImplementationProcess",
    {"india": ind},
    "ALIVE",
    state="Delhi",
    healthcare_resource_cost=0.1,
    main_scale=0.1,
)

k = []
for i in range(10):
    k.append(Aid_kit_process.run(i))
    ind.sync()

k
# Out:
# [{'AidKitImplementationProcess_Maharashtra_india': 0.01,
#   'AidKitImplementationProcess_Delhi_india': 0.009966275408248296,
#   'AidKitImplementationProcess_Uttar Pradesh_india': 0.01,
#   'AidKitImplementationProcess_Rajasthan_india': 0.01,
#   'AidKitImplementationProcess_Kerala_india': 0.01,
#   'AidKitImplementationProcess_West Bengal_india': 0.01,
#   'AidKitImplementationProcess_Gujarat_india': 0.01},
#  {'AidKitImplementationProcess_Maharashtra_india': 0.01,
#   'AidKitImplementationProcess_Delhi_india': 0.009962909210826612,
#   'AidKitImplementationProcess_Uttar Pradesh_india': 0.01,
#   'AidKitImplementationProcess_Rajasthan_india': 0.01,
#   'AidKitImplementationProcess_Kerala_india': 0.01,
#   'AidKitImplementationProcess_West Bengal_india': 0.01,
#   'AidKitImplementationProcess_Gujarat_india': 0.01},
#  {'AidKitImplementationProcess_Maharashtra_india': 0.01,
#   'AidKitImplementationProcess_Delhi_india': 0.009959544150367795,
#   'AidKitImplementationProcess_Uttar Pradesh_india': 0.01,
#   'AidKitImplementationProcess_Rajasthan_india': 0.01,
#   'AidKitImplementationProcess_Kerala_india': 0.01,
#   'AidKitImplementationProcess_West Bengal_india': 0.01,
#   'AidKitImplementationProcess_Gujarat_india': 0.01},
#  {'AidKitImplementationProcess_Maharashtra_india': 0.01,
#   'AidKitImplementationProcess_Delhi_india': 0.009956180226487829,
#   'AidKitImplementationProcess_Uttar Pradesh_india': 0.01,
#   'AidKitImplementationProcess_Rajasthan_india': 0.01,
#   'AidKitImplementationProcess_Kerala_india': 0.01,
#   'AidKitImplementationProcess_West Bengal_india': 0.01,
#   'AidKitImplementationProcess_Gujarat_india': 0.01},
#  {'AidKitImplementationProcess_Maharashtra_india': 0.01,
#   'AidKitImplementationProcess_Delhi_india': 0.009952817438802823,
#   'AidKitImplementationProcess_Uttar Pradesh_india': 0.01,
#   'AidKitImplementationProcess_Rajasthan_india': 0.01,
#   'AidKitImplementationProcess_Kerala_india': 0.01,
#   'AidKitImplementationProcess_West Bengal_india': 0.01,
#   'AidKitImplementationProcess_Gujarat_india': 0.01},
#  {'AidKitImplementationProcess_Maharashtra_india': 0.01,
#   'AidKitImplementationProcess_Delhi_india': 0.009949455786929018,
#   'AidKitImplementationProcess_Uttar Pradesh_india': 0.01,
#   'AidKitImplementationProcess_Rajasthan_india': 0.01,
#   'AidKitImplementationProcess_Kerala_india': 0.01,
#   'AidKitImplementationProcess_West Bengal_india': 0.01,
#   'AidKitImplementationProcess_Gujarat_india': 0.01},
#  {'AidKitImplementationProcess_Maharashtra_india': 0.01,
#   'AidKitImplementationProcess_Delhi_india': 0.009946095270482782,
#   'AidKitImplementationProcess_Uttar Pradesh_india': 0.01,
#   'AidKitImplementationProcess_Rajasthan_india': 0.01,
#   'AidKitImplementationProcess_Kerala_india': 0.01,
#   'AidKitImplementationProcess_West Bengal_india': 0.01,
#   'AidKitImplementationProcess_Gujarat_india': 0.01},
#  {'AidKitImplementationProcess_Maharashtra_india': 0.01,
#   'AidKitImplementationProcess_Delhi_india': 0.009942735889080616,
#   'AidKitImplementationProcess_Uttar Pradesh_india': 0.01,
#   'AidKitImplementationProcess_Rajasthan_india': 0.01,
#   'AidKitImplementationProcess_Kerala_india': 0.01,
#   'AidKitImplementationProcess_West Bengal_india': 0.01,
#   'AidKitImplementationProcess_Gujarat_india': 0.01},
#  {'AidKitImplementationProcess_Maharashtra_india': 0.01,
#   'AidKitImplementationProcess_Delhi_india': 0.009939377642339148,
#   'AidKitImplementationProcess_Uttar Pradesh_india': 0.01,
#   'AidKitImplementationProcess_Rajasthan_india': 0.01,
#   'AidKitImplementationProcess_Kerala_india': 0.01,
#   'AidKitImplementationProcess_West Bengal_india': 0.01,
#   'AidKitImplementationProcess_Gujarat_india': 0.01},
#  {'AidKitImplementationProcess_Maharashtra_india': 0.01,
#   'AidKitImplementationProcess_Delhi_india': 0.009936020529875137,
#   'AidKitImplementationProcess_Uttar Pradesh_india': 0.01,
#   'AidKitImplementationProcess_Rajasthan_india': 0.01,
#   'AidKitImplementationProcess_Kerala_india': 0.01,
#   'AidKitImplementationProcess_West Bengal_india': 0.01,
#   'AidKitImplementationProcess_Gujarat_india': 0.01}]

# %% [markdown]
# ### General Sanitation Implementation  (Reduce Vaue)

# %%
# Make General_Sanitation_Implementation class similar to the above processes structure

class General_Sanitation_Implementation(ProcessV1):
    RANK = 1
    DOMAIN = (gpe.Country,)

    def __init__(
        self,
        id: str,
        entities,
        status: str,
        state,
        sanitation_equipment_cost,
        main_scale,
    ):
        super().__init__(id, entities, status)
        self.state = state
        self.sanitation_equipment_cost = sanitation_equipment_cost
        self.main_scale = main_scale
        self.status = status

    def while_dormant(self, step: int):
        pass

    def while_alive(self, step: int):
        for country in self.entities:
            sanitation_equipment = self.entities[country].sanitation_equipment_stockpile

            for locus in self.entities[country].loci:
                if locus.name == self.state:
                    if sanitation_equipment >= self.sanitation_equipment_cost:
                        if (
                            self.entities[country].sanitation_equipment_stockpile
                            - self.sanitation_equipment_cost
                            <= 0
                        ):
                            self.entities[country].sanitation_equipment_stockpile = 0
                        else:
                            self.entities[
                                country
                            ].sanitation_equipment_stockpile -= (
                                self.sanitation_equipment_cost
                            )

                        if (
                            locus.B
                            - (
                                locus.B
                                * self.main_scale
                                * (locus.infected + locus.susceptible)
                                / (5e9)
                            )
                            >= 0
                        ):
                            locus.B -= (
                                locus.B
                                * self.main_scale
                                * (locus.infected + locus.susceptible)
                                / (5e9)
                            )
                        else:
                            locus.B -= 0
                    else:
                        locus.B -= 0

        return {
            "General_Sanitation_Implementation"
            + "_"
            + str(locus.name)
            + "_"
            + str(country): locus.B
            for locus in self.entities[country].loci
        }

# %%
Sanitation_Implementation = General_Sanitation_Implementation(
    "General_Sanitation_Implementation",
    {"india": ind},
    "ALIVE",
    state="Rajasthan",
    sanitation_equipment_cost=0.1,
    main_scale=0.3,
)

k = []
for i in range(10):
    k.append(Sanitation_Implementation.run(i))
    ind.sync()

k
# Out:
# [{'ALIVE/General_Sanitation_Implementation_Maharashtra_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Delhi_india': 0.00993266455130547,
#   'ALIVE/General_Sanitation_Implementation_Uttar Pradesh_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Rajasthan_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Kerala_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_West Bengal_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Gujarat_india': 0.01},
#  {'ALIVE/General_Sanitation_Implementation_Maharashtra_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Delhi_india': 0.00993266455130547,
#   'ALIVE/General_Sanitation_Implementation_Uttar Pradesh_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Rajasthan_india': 0.0099588109378,
#   'ALIVE/General_Sanitation_Implementation_Kerala_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_West Bengal_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Gujarat_india': 0.01},
#  {'ALIVE/General_Sanitation_Implementation_Maharashtra_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Delhi_india': 0.00993266455130547,
#   'ALIVE/General_Sanitation_Implementation_Uttar Pradesh_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Rajasthan_india': 0.009917791529484491,
#   'ALIVE/General_Sanitation_Implementation_Kerala_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_West Bengal_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Gujarat_india': 0.01},
#  {'ALIVE/General_Sanitation_Implementation_Maharashtra_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Delhi_india': 0.00993266455130547,
#   'ALIVE/General_Sanitation_Implementation_Uttar Pradesh_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Rajasthan_india': 0.009876941076265034,
#   'ALIVE/General_Sanitation_Implementation_Kerala_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_West Bengal_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Gujarat_india': 0.01},
#  {'ALIVE/General_Sanitation_Implementation_Maharashtra_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Delhi_india': 0.00993266455130547,
#   'ALIVE/General_Sanitation_Implementation_Uttar Pradesh_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Rajasthan_india': 0.009836258882231433,
#   'ALIVE/General_Sanitation_Implementation_Kerala_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_West Bengal_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Gujarat_india': 0.01},
#  {'ALIVE/General_Sanitation_Implementation_Maharashtra_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Delhi_india': 0.00993266455130547,
#   'ALIVE/General_Sanitation_Implementation_Uttar Pradesh_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Rajasthan_india': 0.00979574425433988,
#   'ALIVE/General_Sanitation_Implementation_Kerala_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_West Bengal_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Gujarat_india': 0.01},
#  {'ALIVE/General_Sanitation_Implementation_Maharashtra_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Delhi_india': 0.00993266455130547,
#   'ALIVE/General_Sanitation_Implementation_Uttar Pradesh_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Rajasthan_india': 0.00975539650240115,
#   'ALIVE/General_Sanitation_Implementation_Kerala_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_West Bengal_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Gujarat_india': 0.01},
#  {'ALIVE/General_Sanitation_Implementation_Maharashtra_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Delhi_india': 0.00993266455130547,
#   'ALIVE/General_Sanitation_Implementation_Uttar Pradesh_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Rajasthan_india': 0.009715214939068843,
#   'ALIVE/General_Sanitation_Implementation_Kerala_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_West Bengal_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Gujarat_india': 0.01},
#  {'ALIVE/General_Sanitation_Implementation_Maharashtra_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Delhi_india': 0.00993266455130547,
#   'ALIVE/General_Sanitation_Implementation_Uttar Pradesh_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Rajasthan_india': 0.009675198879827675,
#   'ALIVE/General_Sanitation_Implementation_Kerala_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_West Bengal_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Gujarat_india': 0.01},
#  {'ALIVE/General_Sanitation_Implementation_Maharashtra_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Delhi_india': 0.00993266455130547,
#   'ALIVE/General_Sanitation_Implementation_Uttar Pradesh_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Rajasthan_india': 0.009635347642981816,
#   'ALIVE/General_Sanitation_Implementation_Kerala_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_West Bengal_india': 0.01,
#   'ALIVE/General_Sanitation_Implementation_Gujarat_india': 0.01}]

# %% [markdown]
# ### Environmental Cleaning Implementation  (Reduce Vaue)

# %%
# Make EnvironmentalCleaningProcess class similar to the above processes structure
class EnvironmentalCleaningProcess(ProcessV1):
    RANK = 1
    DOMAIN = (gpe.Country,)

    def __init__(
        self,
        id: str,
        entities,
        status: str,
        state,
        environmental_cleaning_cost,
        main_scale,
    ):
        super().__init__(id, entities, status)
        self.state = state
        self.environmental_cleaning_cost = environmental_cleaning_cost
        self.main_scale = main_scale
        self.status = status

    def while_dormant(self, step: int):
        pass

    def while_alive(self, step: int):
        for country in self.entities:
            environmental_cleaning = self.entities[
                country
            ].sanitation_equipment_stockpile

            for locus in self.entities[country].loci:
                if locus.name == self.state:
                    if environmental_cleaning >= self.environmental_cleaning_cost:
                        if (
                            self.entities[country].sanitation_equipment_stockpile
                            - self.environmental_cleaning_cost
                            <= 0
                        ):
                            self.entities[country].environmental_cleaning_stockpile = 0
                        else:
                            self.entities[
                                country
                            ].sanitation_equipment_stockpile -= (
                                self.environmental_cleaning_cost
                            )
                        if (
                            locus.B
                            - (
                                locus.B
                                * self.main_scale
                                * (locus.infected + locus.susceptible)
                                / (5e9)
                            )
                            >= 0
                        ):
                            locus.B -= (
                                locus.B
                                * self.main_scale
                                * (locus.infected + locus.susceptible)
                                / (5e9)
                            )
                        else:
                            locus.B -= 0
                    else:
                        locus.B -= 0
        return {
            "EnvironmentalCleaningProcess"
            + "_"
            + str(locus.name)
            + "_"
            + str(country): locus.B
            for locus in self.entities[country].loci
        }

    def run(self, step: int):
        return self.while_alive(step)

# %%
environmental_cleaning_process = EnvironmentalCleaningProcess(
    "EnvironmentalCleaningProcess",
    {"india": ind},
    "ALIVE",
    state="Kerala",
    environmental_cleaning_cost=0.1,
    main_scale=0.3,
)

k = []
for i in range(10):
    k.append(environmental_cleaning_process.run(i))
    ind.sync()

k
# Out:
# [{'EnvironmentalCleaningProcess_Maharashtra_india': 0.01,
#   'EnvironmentalCleaningProcess_Delhi_india': 0.00993266455130547,
#   'EnvironmentalCleaningProcess_Uttar Pradesh_india': 0.01,
#   'EnvironmentalCleaningProcess_Rajasthan_india': 0.009595660549643276,
#   'EnvironmentalCleaningProcess_Kerala_india': 0.01,
#   'EnvironmentalCleaningProcess_West Bengal_india': 0.01,
#   'EnvironmentalCleaningProcess_Gujarat_india': 0.01},
#  {'EnvironmentalCleaningProcess_Maharashtra_india': 0.01,
#   'EnvironmentalCleaningProcess_Delhi_india': 0.00993266455130547,
#   'EnvironmentalCleaningProcess_Uttar Pradesh_india': 0.01,
#   'EnvironmentalCleaningProcess_Rajasthan_india': 0.009595660549643276,
#   'EnvironmentalCleaningProcess_Kerala_india': 0.0099798963634,
#   'EnvironmentalCleaningProcess_West Bengal_india': 0.01,
#   'EnvironmentalCleaningProcess_Gujarat_india': 0.01},
#  {'EnvironmentalCleaningProcess_Maharashtra_india': 0.01,
#   'EnvironmentalCleaningProcess_Delhi_india': 0.00993266455130547,
#   'EnvironmentalCleaningProcess_Uttar Pradesh_india': 0.01,
#   'EnvironmentalCleaningProcess_Rajasthan_india': 0.009595660549643276,
#   'EnvironmentalCleaningProcess_Kerala_india': 0.009959833142420453,
#   'EnvironmentalCleaningProcess_West Bengal_india': 0.01,
#   'EnvironmentalCleaningProcess_Gujarat_india': 0.01},
#  {'EnvironmentalCleaningProcess_Maharashtra_india': 0.01,
#   'EnvironmentalCleaningProcess_Delhi_india': 0.00993266455130547,
#   'EnvironmentalCleaningProcess_Uttar Pradesh_india': 0.01,
#   'EnvironmentalCleaningProcess_Rajasthan_india': 0.009595660549643276,
#   'EnvironmentalCleaningProcess_Kerala_india': 0.009939810255811268,
#   'EnvironmentalCleaningProcess_West Bengal_india': 0.01,
#   'EnvironmentalCleaningProcess_Gujarat_india': 0.01},
#  {'EnvironmentalCleaningProcess_Maharashtra_india': 0.01,
#   'EnvironmentalCleaningProcess_Delhi_india': 0.00993266455130547,
#   'EnvironmentalCleaningProcess_Uttar Pradesh_india': 0.01,
#   'EnvironmentalCleaningProcess_Rajasthan_india': 0.009595660549643276,
#   'EnvironmentalCleaningProcess_Kerala_india': 0.00991982762248569,
#   'EnvironmentalCleaningProcess_West Bengal_india': 0.01,
#   'EnvironmentalCleaningProcess_Gujarat_india': 0.01},
#  {'EnvironmentalCleaningProcess_Maharashtra_india': 0.01,
#   'EnvironmentalCleaningProcess_Delhi_india': 0.00993266455130547,
#   'EnvironmentalCleaningProcess_Uttar Pradesh_india': 0.01,
#   'EnvironmentalCleaningProcess_Rajasthan_india': 0.009595660549643276,
#   'EnvironmentalCleaningProcess_Kerala_india': 0.00989988516151998,
#   'EnvironmentalCleaningProcess_West Bengal_india': 0.01,
#   'EnvironmentalCleaningProcess_Gujarat_india': 0.01},
#  {'EnvironmentalCleaningProcess_Maharashtra_india': 0.01,
#   'EnvironmentalCleaningProcess_Delhi_india': 0.00993266455130547,
#   'EnvironmentalCleaningProcess_Uttar Pradesh_india': 0.01,
#   'EnvironmentalCleaningProcess_Rajasthan_india': 0.009595660549643276,
#   'EnvironmentalCleaningProcess_Kerala_india': 0.009879982792153087,
#   'EnvironmentalCleaningProcess_West Bengal_india': 0.01,
#   'EnvironmentalCleaningProcess_Gujarat_india': 0.01},
#  {'EnvironmentalCleaningProcess_Maharashtra_india': 0.01,
#   'EnvironmentalCleaningProcess_Delhi_india': 0.00993266455130547,
#   'EnvironmentalCleaningProcess_Uttar Pradesh_india': 0.01,
#   'EnvironmentalCleaningProcess_Rajasthan_india': 0.009595660549643276,
#   'EnvironmentalCleaningProcess_Kerala_india': 0.009860120433786318,
#   'EnvironmentalCleaningProcess_West Bengal_india': 0.01,
#   'EnvironmentalCleaningProcess_Gujarat_india': 0.01},
#  {'EnvironmentalCleaningProcess_Maharashtra_india': 0.01,
#   'EnvironmentalCleaningProcess_Delhi_india': 0.00993266455130547,
#   'EnvironmentalCleaningProcess_Uttar Pradesh_india': 0.01,
#   'EnvironmentalCleaningProcess_Rajasthan_india': 0.009595660549643276,
#   'EnvironmentalCleaningProcess_Kerala_india': 0.00984029800598301,
#   'EnvironmentalCleaningProcess_West Bengal_india': 0.01,
#   'EnvironmentalCleaningProcess_Gujarat_india': 0.01},
#  {'EnvironmentalCleaningProcess_Maharashtra_india': 0.01,
#   'EnvironmentalCleaningProcess_Delhi_india': 0.00993266455130547,
#   'EnvironmentalCleaningProcess_Uttar Pradesh_india': 0.01,
#   'EnvironmentalCleaningProcess_Rajasthan_india': 0.009595660549643276,
#   'EnvironmentalCleaningProcess_Kerala_india': 0.00982051542846821,
#   'EnvironmentalCleaningProcess_West Bengal_india': 0.01,
#   'EnvironmentalCleaningProcess_Gujarat_india': 0.01}]

# %% [markdown]
# ### Changing Effect size of Economic Zones (Indirect impact on B Parameter) (Reduces B and GDP trickle from Zone)

# %%
class EconomicZoneEffectChangeProcess(ProcessV1):
    RANK = 1
    DOMAIN = (gpe.Country,)

    def __init__(
        self,
        id: str,
        entities,
        status: str,
        change_country,
        economic_zone_names,
        effect,
    ):

        # Give Country and economic zone name as list with same index corresponding to each others country (with same name as Initialized Entity) and economic zone name

        super().__init__(id, entities, status)
        self.change_country = change_country
        self.economic_zone_names = economic_zone_names
        self.effect = effect
        self.status = status

    def while_dormant(self, step: int):
        pass

    def while_alive(self, step: int):
        if len(self.change_country) != len(self.economic_zone_names):
            raise ValueError(
                "Length of change country, economic_zone_name and effect should be same"
            )

        elif len(self.change_country) == 0:
            print("here")
            # go through all the countries and increase the B value of locus based on available economic zone and its b_value_increase
            for country in self.entities.keys():
                for locus in self.entities[country].loci:
                    total_b_increase = 0
                    for economicZone in locus.economic_zones:
                        total_b_increase += economicZone["b_val_increase"]
                    locus.B += total_b_increase

        elif len(self.change_country) > 0 and len(self.change_country) == len(
            self.economic_zone_names
        ):
            #print("in")
            for i, country in enumerate(self.change_country):
                b_vals = [0.0005, 0.0003, 0.0001]
                for locus in self.entities[country].loci:
                    for economicZone in locus.economic_zones:
                        #print(economicZone["name"])
                        if economicZone["name"] == self.economic_zone_names[i]:
                            #print("Yes")
                            economicZone["effect"] = self.effect[i]
                            economicZone["b_val_increase"] = float(b_vals[economicZone["zone_tier"]] * economicZone["effect"])
                        break
                    break
            #print("here")
                            

            # got through all cities and increase the B value of locus based on available economic zone and its b_value_increase
            for country in self.entities.keys():
                for locus in self.entities[country].loci:
                    total_b_increase = 0
                    if locus.economic_zones != None:
                        for economicZone in locus.economic_zones:
                            #print(economicZone["name"], economicZone["b_val_increase"])
                            total_b_increase += economicZone["b_val_increase"]
                        #print(locus.name, total_b_increase, "name", "Increase")
                        locus.B += total_b_increase
        return {
            "EconomicZoneEffectChangeProcess"
            + "_"
            + str(locus.name)
            + "_"
            + str(country): locus.B
            for locus in self.entities[country].loci
        }

    def run(self, step):
        if self.status == "ALIVE":
            return self.while_alive(step)

# %%
economic_zone_effect_change_process = EconomicZoneEffectChangeProcess(
    "EconomicZoneEffectChangeProcess",
    {"india": ind},  # give all counties to this entity here
    "ALIVE",
    change_country=["india"],
    economic_zone_names=["Ahmedabad SEZ"]],
    effect=0.5,
)

k = []
for i in range(10):
    k.append(economic_zone_effect_change_process.run(i))
    ind.sync()

k
# Out:
# [{'EconomicZoneEffectChangeProcess_Maharashtra_india': 0.01,
#   'EconomicZoneEffectChangeProcess_Delhi_india': 0.00993266455130547,
#   'EconomicZoneEffectChangeProcess_Uttar Pradesh_india': 0.01,
#   'EconomicZoneEffectChangeProcess_Rajasthan_india': 0.009595660549643276,
#   'EconomicZoneEffectChangeProcess_Kerala_india': 0.00980077262112835,
#   'EconomicZoneEffectChangeProcess_West Bengal_india': 0.01,
#   'EconomicZoneEffectChangeProcess_Gujarat_india': 0.01},
#  {'EconomicZoneEffectChangeProcess_Maharashtra_india': 0.01007,
#   'EconomicZoneEffectChangeProcess_Delhi_india': 0.010002664551305471,
#   'EconomicZoneEffectChangeProcess_Uttar Pradesh_india': 0.01005,
#   'EconomicZoneEffectChangeProcess_Rajasthan_india': 0.009645660549643276,
#   'EconomicZoneEffectChangeProcess_Kerala_india': 0.009850772621128349,
#   'EconomicZoneEffectChangeProcess_West Bengal_india': 0.01006,
#   'EconomicZoneEffectChangeProcess_Gujarat_india': 0.01006},
#  {'EconomicZoneEffectChangeProcess_Maharashtra_india': 0.010140000000000001,
#   'EconomicZoneEffectChangeProcess_Delhi_india': 0.010072664551305472,
#   'EconomicZoneEffectChangeProcess_Uttar Pradesh_india': 0.0101,
#   'EconomicZoneEffectChangeProcess_Rajasthan_india': 0.009695660549643275,
#   'EconomicZoneEffectChangeProcess_Kerala_india': 0.009900772621128349,
#   'EconomicZoneEffectChangeProcess_West Bengal_india': 0.010119999999999999,
#   'EconomicZoneEffectChangeProcess_Gujarat_india': 0.010119999999999999},
#  {'EconomicZoneEffectChangeProcess_Maharashtra_india': 0.010210000000000002,
#   'EconomicZoneEffectChangeProcess_Delhi_india': 0.010142664551305473,
#   'EconomicZoneEffectChangeProcess_Uttar Pradesh_india': 0.01015,
#   'EconomicZoneEffectChangeProcess_Rajasthan_india': 0.009745660549643275,
#   'EconomicZoneEffectChangeProcess_Kerala_india': 0.009950772621128348,
#   'EconomicZoneEffectChangeProcess_West Bengal_india': 0.010179999999999998,
#   'EconomicZoneEffectChangeProcess_Gujarat_india': 0.010179999999999998},
#  {'EconomicZoneEffectChangeProcess_Maharashtra_india': 0.010280000000000003,
#   'EconomicZoneEffectChangeProcess_Delhi_india': 0.010212664551305473,
#   'EconomicZoneEffectChangeProcess_Uttar Pradesh_india': 0.010199999999999999,
#   'EconomicZoneEffectChangeProcess_Rajasthan_india': 0.009795660549643275,
#   'EconomicZoneEffectChangeProcess_Kerala_india': 0.010000772621128348,
#   'EconomicZoneEffectChangeProcess_West Bengal_india': 0.010239999999999997,
#   'EconomicZoneEffectChangeProcess_Gujarat_india': 0.010239999999999997},
#  {'EconomicZoneEffectChangeProcess_Maharashtra_india': 0.010350000000000003,
#   'EconomicZoneEffectChangeProcess_Delhi_india': 0.010282664551305474,
#   'EconomicZoneEffectChangeProcess_Uttar Pradesh_india': 0.010249999999999999,
#   'EconomicZoneEffectChangeProcess_Rajasthan_india': 0.009845660549643274,
#   'EconomicZoneEffectChangeProcess_Kerala_india': 0.010050772621128348,
#   'EconomicZoneEffectChangeProcess_West Bengal_india': 0.010299999999999997,
#   'EconomicZoneEffectChangeProcess_Gujarat_india': 0.010299999999999997},
#  {'EconomicZoneEffectChangeProcess_Maharashtra_india': 0.010420000000000004,
#   'EconomicZoneEffectChangeProcess_Delhi_india': 0.010352664551305474,
#   'EconomicZoneEffectChangeProcess_Uttar Pradesh_india': 0.010299999999999998,
#   'EconomicZoneEffectChangeProcess_Rajasthan_india': 0.009895660549643274,
#   'EconomicZoneEffectChangeProcess_Kerala_india': 0.010100772621128348,
#   'EconomicZoneEffectChangeProcess_West Bengal_india': 0.010359999999999996,
#   'EconomicZoneEffectChangeProcess_Gujarat_india': 0.010359999999999996},
#  {'EconomicZoneEffectChangeProcess_Maharashtra_india': 0.010490000000000005,
#   'EconomicZoneEffectChangeProcess_Delhi_india': 0.010422664551305475,
#   'EconomicZoneEffectChangeProcess_Uttar Pradesh_india': 0.010349999999999998,
#   'EconomicZoneEffectChangeProcess_Rajasthan_india': 0.009945660549643274,
#   'EconomicZoneEffectChangeProcess_Kerala_india': 0.010150772621128347,
#   'EconomicZoneEffectChangeProcess_West Bengal_india': 0.010419999999999995,
#   'EconomicZoneEffectChangeProcess_Gujarat_india': 0.010419999999999995},
#  {'EconomicZoneEffectChangeProcess_Maharashtra_india': 0.010560000000000005,
#   'EconomicZoneEffectChangeProcess_Delhi_india': 0.010492664551305476,
#   'EconomicZoneEffectChangeProcess_Uttar Pradesh_india': 0.010399999999999998,
#   'EconomicZoneEffectChangeProcess_Rajasthan_india': 0.009995660549643274,
#   'EconomicZoneEffectChangeProcess_Kerala_india': 0.010200772621128347,
#   'EconomicZoneEffectChangeProcess_West Bengal_india': 0.010479999999999995,
#   'EconomicZoneEffectChangeProcess_Gujarat_india': 0.010479999999999995},
#  {'EconomicZoneEffectChangeProcess_Maharashtra_india': 0.010630000000000006,
#   'EconomicZoneEffectChangeProcess_Delhi_india': 0.010562664551305476,
#   'EconomicZoneEffectChangeProcess_Uttar Pradesh_india': 0.010449999999999997,
#   'EconomicZoneEffectChangeProcess_Rajasthan_india': 0.010045660549643273,
#   'EconomicZoneEffectChangeProcess_Kerala_india': 0.010250772621128347,
#   'EconomicZoneEffectChangeProcess_West Bengal_india': 0.010539999999999994,
#   'EconomicZoneEffectChangeProcess_Gujarat_india': 0.010539999999999994}]

# %% [markdown]
# ### Changing tourist areas effect and then updates B value or If not provided with area to affect will do its regular increase to all regions

# %%
class TouristZoneEffectChangeProcess(ProcessV1):
    RANK = 1
    DOMAIN = (gpe.Country,)

    def __init__(
        self,
        id: str,
        entities,
        status: str,
        change_country,
        tourist_zone_names,
        effect,
    ):

        # Give Country and economic zone name as list with same index corresponding to each others country (with same name as Initialized Entity) and economic zone name

        super().__init__(id, entities, status)
        self.change_country = change_country
        self.tourist_zone_names = tourist_zone_names
        self.effect = effect
        self.status = status

    def while_dormant(self, step: int):
        pass

    def while_alive(self, step: int):
        if len(self.change_country) != len(self.tourist_zone_names):
            raise ValueError(
                "Length of change country, economic_zone_name and effect should be same"
            )

        elif len(self.change_country) == 0:
            print("here")
            # go through all the countries and increase the B value of locus based on available economic zone and its b_value_increase
            for country in self.entities.keys():
                for locus in self.entities[country].loci:
                    total_b_increase = 0
                    for touristZone in locus.tourist_zones:
                        total_b_increase += touristZone["b_val_increase"]
                    locus.B += total_b_increase

        elif len(self.change_country) > 0 and len(self.change_country) == len(
            self.tourist_zone_names
        ):
            #print("in")
            for i, country in enumerate(self.change_country):
                b_vals = [0.0005, 0.0003, 0.0001]
                for locus in self.entities[country].loci:
                    for touristZone in locus.tourist_zones:
                        #print(touristZone["name"])
                        if touristZone["name"] == self.tourist_zone_names[i]:
                            #print("Yes")
                            touristZone["effect"] = self.effect[i]
                            touristZone["b_val_increase"] = float(b_vals[touristZone["zone_tier"]] * touristZone["effect"])
                        break
                    break
            #print("here")
                            

            # got through all cities and increase the B value of locus based on available economic zone and its b_value_increase
            for country in self.entities.keys():
                for locus in self.entities[country].loci:
                    total_b_increase = 0
                    if locus.tourist_zones != None:
                        for touristZone in locus.tourist_zones:
                            #print(touristZone["name"], touristZone["b_val_increase"])
                            total_b_increase += touristZone["b_val_increase"]
                        #print(locus.name, total_b_increase, "name", "Increase")
                        locus.B += total_b_increase
                        #print(locus.B, "increaseB")
                    

        return {
            "TouristZoneEffectChangeProcess"
            + "_"
            + str(locus.name)
            + "_"
            + str(country): locus.B
            for locus in self.entities[country].loci
        }

    def run(self, step: int):
        if self.status == "ALIVE":
            return self.while_alive(step)

# %%
tourist_zone_effect_change_process = TouristZoneEffectChangeProcess(
    "TouristZoneEffectChangeProcess",
    {"india": ind},  # give all counties to this entity here
    "ALIVE",
    change_country=["india"],
    tourist_zone_names=["Sabarmati Ashram"],
    effect=[0.0],
)

k = []
for i in range(10):
    k.append(tourist_zone_effect_change_process.run(i))
    ind.sync()

k
# Out:
# [{'TouristZoneEffectChangeProcess_Maharashtra_india': 0.010700000000000006,
#   'TouristZoneEffectChangeProcess_Delhi_india': 0.010632664551305477,
#   'TouristZoneEffectChangeProcess_Uttar Pradesh_india': 0.010499999999999997,
#   'TouristZoneEffectChangeProcess_Rajasthan_india': 0.010095660549643273,
#   'TouristZoneEffectChangeProcess_Kerala_india': 0.010300772621128346,
#   'TouristZoneEffectChangeProcess_West Bengal_india': 0.010599999999999993,
#   'TouristZoneEffectChangeProcess_Gujarat_india': 0.010599999999999993},
#  {'TouristZoneEffectChangeProcess_Maharashtra_india': 0.010770000000000007,
#   'TouristZoneEffectChangeProcess_Delhi_india': 0.010702664551305478,
#   'TouristZoneEffectChangeProcess_Uttar Pradesh_india': 0.010559999999999996,
#   'TouristZoneEffectChangeProcess_Rajasthan_india': 0.010165660549643274,
#   'TouristZoneEffectChangeProcess_Kerala_india': 0.010370772621128347,
#   'TouristZoneEffectChangeProcess_West Bengal_india': 0.010649999999999993,
#   'TouristZoneEffectChangeProcess_Gujarat_india': 0.010649999999999993},
#  {'TouristZoneEffectChangeProcess_Maharashtra_india': 0.010840000000000008,
#   'TouristZoneEffectChangeProcess_Delhi_india': 0.010772664551305478,
#   'TouristZoneEffectChangeProcess_Uttar Pradesh_india': 0.010619999999999996,
#   'TouristZoneEffectChangeProcess_Rajasthan_india': 0.010235660549643274,
#   'TouristZoneEffectChangeProcess_Kerala_india': 0.010440772621128348,
#   'TouristZoneEffectChangeProcess_West Bengal_india': 0.010699999999999993,
#   'TouristZoneEffectChangeProcess_Gujarat_india': 0.010699999999999993},
#  {'TouristZoneEffectChangeProcess_Maharashtra_india': 0.010910000000000008,
#   'TouristZoneEffectChangeProcess_Delhi_india': 0.010842664551305479,
#   'TouristZoneEffectChangeProcess_Uttar Pradesh_india': 0.010679999999999995,
#   'TouristZoneEffectChangeProcess_Rajasthan_india': 0.010305660549643275,
#   'TouristZoneEffectChangeProcess_Kerala_india': 0.010510772621128348,
#   'TouristZoneEffectChangeProcess_West Bengal_india': 0.010749999999999992,
#   'TouristZoneEffectChangeProcess_Gujarat_india': 0.010749999999999992},
#  {'TouristZoneEffectChangeProcess_Maharashtra_india': 0.010980000000000009,
#   'TouristZoneEffectChangeProcess_Delhi_india': 0.01091266455130548,
#   'TouristZoneEffectChangeProcess_Uttar Pradesh_india': 0.010739999999999994,
#   'TouristZoneEffectChangeProcess_Rajasthan_india': 0.010375660549643275,
#   'TouristZoneEffectChangeProcess_Kerala_india': 0.010580772621128349,
#   'TouristZoneEffectChangeProcess_West Bengal_india': 0.010799999999999992,
#   'TouristZoneEffectChangeProcess_Gujarat_india': 0.010799999999999992},
#  {'TouristZoneEffectChangeProcess_Maharashtra_india': 0.01105000000000001,
#   'TouristZoneEffectChangeProcess_Delhi_india': 0.01098266455130548,
#   'TouristZoneEffectChangeProcess_Uttar Pradesh_india': 0.010799999999999994,
#   'TouristZoneEffectChangeProcess_Rajasthan_india': 0.010445660549643276,
#   'TouristZoneEffectChangeProcess_Kerala_india': 0.01065077262112835,
#   'TouristZoneEffectChangeProcess_West Bengal_india': 0.010849999999999992,
#   'TouristZoneEffectChangeProcess_Gujarat_india': 0.010849999999999992},
#  {'TouristZoneEffectChangeProcess_Maharashtra_india': 0.01112000000000001,
#   'TouristZoneEffectChangeProcess_Delhi_india': 0.01105266455130548,
#   'TouristZoneEffectChangeProcess_Uttar Pradesh_india': 0.010859999999999993,
#   'TouristZoneEffectChangeProcess_Rajasthan_india': 0.010515660549643277,
#   'TouristZoneEffectChangeProcess_Kerala_india': 0.01072077262112835,
#   'TouristZoneEffectChangeProcess_West Bengal_india': 0.010899999999999991,
#   'TouristZoneEffectChangeProcess_Gujarat_india': 0.010899999999999991},
#  {'TouristZoneEffectChangeProcess_Maharashtra_india': 0.01119000000000001,
#   'TouristZoneEffectChangeProcess_Delhi_india': 0.011122664551305481,
#   'TouristZoneEffectChangeProcess_Uttar Pradesh_india': 0.010919999999999992,
#   'TouristZoneEffectChangeProcess_Rajasthan_india': 0.010585660549643277,
#   'TouristZoneEffectChangeProcess_Kerala_india': 0.01079077262112835,
#   'TouristZoneEffectChangeProcess_West Bengal_india': 0.010949999999999991,
#   'TouristZoneEffectChangeProcess_Gujarat_india': 0.010949999999999991},
#  {'TouristZoneEffectChangeProcess_Maharashtra_india': 0.011260000000000011,
#   'TouristZoneEffectChangeProcess_Delhi_india': 0.011192664551305482,
#   'TouristZoneEffectChangeProcess_Uttar Pradesh_india': 0.010979999999999992,
#   'TouristZoneEffectChangeProcess_Rajasthan_india': 0.010655660549643278,
#   'TouristZoneEffectChangeProcess_Kerala_india': 0.010860772621128351,
#   'TouristZoneEffectChangeProcess_West Bengal_india': 0.01099999999999999,
#   'TouristZoneEffectChangeProcess_Gujarat_india': 0.01099999999999999},
#  {'TouristZoneEffectChangeProcess_Maharashtra_india': 0.011330000000000012,
#   'TouristZoneEffectChangeProcess_Delhi_india': 0.011262664551305483,
#   'TouristZoneEffectChangeProcess_Uttar Pradesh_india': 0.01103999999999999,
#   'TouristZoneEffectChangeProcess_Rajasthan_india': 0.010725660549643279,
#   'TouristZoneEffectChangeProcess_Kerala_india': 0.010930772621128352,
#   'TouristZoneEffectChangeProcess_West Bengal_india': 0.01104999999999999,
#   'TouristZoneEffectChangeProcess_Gujarat_india': 0.01104999999999999}]

# %%
class PortEffectChangeProcess(ProcessV1):
    RANK = 1
    DOMAIN = (gpe.Country,)

    def __init__(
        self,
        id: str,
        entities,
        status: str,
        change_country,
        port_names,
        effect,
    ):

        # Give Country and economic zone name as list with same index corresponding to each others country (with same name as Initialized Entity) and economic zone name

        super().__init__(id, entities, status)
        self.change_country = change_country
        self.port_names = port_names
        self.effect = effect
        self.status = status

    def while_dormant(self, step: int):
        pass

    def while_alive(self, step: int):
        if len(self.change_country) != len(self.port_names):
            raise ValueError(
                "Length of change country, economic_zone_name and effect should be same"
            )

        elif len(self.change_country) == 0:
            print("here")
            # go through all the countries and increase the B value of locus based on available economic zone and its b_value_increase
            for country in self.entities.keys():
                for locus in self.entities[country].loci:
                    total_b_increase = 0
                    for port in locus.ports:
                        total_b_increase += port["b_val_increase"]
                    locus.B += total_b_increase

        elif len(self.change_country) > 0 and len(self.change_country) == len(
            self.port_names
        ):
            #print("in")
            for i, country in enumerate(self.change_country):
                b_vals = [0.005, 0.003, 0.001]
                for locus in self.entities[country].loci:
                    for port in locus.ports:
                        #print(port["name"])
                        if port["name"] == self.port_names[i]:
                            #print("Yes")
                            port["effect"] = self.effect[i]
                            port["b_val_increase"] = float(b_vals[port["zone_tier"]] * port["effect"])
                        break
                    break
            #print("here")
                            

            # got through all cities and increase the B value of locus based on available economic zone and its b_value_increase
            for country in self.entities.keys():
                for locus in self.entities[country].loci:
                    total_b_increase = 0
                    if locus.ports != None:
                        for port in locus.ports:
                            #print(port["name"], port["b_val_increase"])
                            total_b_increase += port["b_val_increase"]
                        #print(locus.name, total_b_increase, "name", "Increase")
                        locus.B += total_b_increase
                        #print(locus.B, "increaseB")
                    

        return {
            "PortEffectChangeProcess"
            + "_"
            + str(locus.name)
            + "_"
            + str(country): locus.B
            for locus in self.entities[country].loci
        }

    def run(self, step: int):
        if self.status == "ALIVE":
            return self.while_alive(step)

# %%
port_effect_change_process = PortEffectChangeProcess(
    "PortEffectChangeProcess",
    {"india": ind},  # give all counties to this entity here
    "ALIVE",
    change_country=["india"],
    port_names=["Kandla Port"],
    effect=[0.0],
)

k = []
for i in range(10):
    k.append(port_effect_change_process.run(i))
    ind.sync()

k
# Out:
# [{'PortEffectChangeProcess_Maharashtra_india': 0.011400000000000013,
#   'PortEffectChangeProcess_Delhi_india': 0.011332664551305483,
#   'PortEffectChangeProcess_Uttar Pradesh_india': 0.01109999999999999,
#   'PortEffectChangeProcess_Rajasthan_india': 0.01079566054964328,
#   'PortEffectChangeProcess_Kerala_india': 0.011000772621128353,
#   'PortEffectChangeProcess_West Bengal_india': 0.01109999999999999,
#   'PortEffectChangeProcess_Gujarat_india': 0.01109999999999999},
#  {'PortEffectChangeProcess_Maharashtra_india': 0.012300000000000012,
#   'PortEffectChangeProcess_Delhi_india': 0.011332664551305483,
#   'PortEffectChangeProcess_Uttar Pradesh_india': 0.01109999999999999,
#   'PortEffectChangeProcess_Rajasthan_india': 0.01079566054964328,
#   'PortEffectChangeProcess_Kerala_india': 0.011800772621128353,
#   'PortEffectChangeProcess_West Bengal_india': 0.01159999999999999,
#   'PortEffectChangeProcess_Gujarat_india': 0.01189999999999999},
#  {'PortEffectChangeProcess_Maharashtra_india': 0.013200000000000012,
#   'PortEffectChangeProcess_Delhi_india': 0.011332664551305483,
#   'PortEffectChangeProcess_Uttar Pradesh_india': 0.01109999999999999,
#   'PortEffectChangeProcess_Rajasthan_india': 0.01079566054964328,
#   'PortEffectChangeProcess_Kerala_india': 0.012600772621128353,
#   'PortEffectChangeProcess_West Bengal_india': 0.012099999999999991,
#   'PortEffectChangeProcess_Gujarat_india': 0.01269999999999999},
#  {'PortEffectChangeProcess_Maharashtra_india': 0.014100000000000012,
#   'PortEffectChangeProcess_Delhi_india': 0.011332664551305483,
#   'PortEffectChangeProcess_Uttar Pradesh_india': 0.01109999999999999,
#   'PortEffectChangeProcess_Rajasthan_india': 0.01079566054964328,
#   'PortEffectChangeProcess_Kerala_india': 0.013400772621128354,
#   'PortEffectChangeProcess_West Bengal_india': 0.012599999999999991,
#   'PortEffectChangeProcess_Gujarat_india': 0.013499999999999991},
#  {'PortEffectChangeProcess_Maharashtra_india': 0.015000000000000012,
#   'PortEffectChangeProcess_Delhi_india': 0.011332664551305483,
#   'PortEffectChangeProcess_Uttar Pradesh_india': 0.01109999999999999,
#   'PortEffectChangeProcess_Rajasthan_india': 0.01079566054964328,
#   'PortEffectChangeProcess_Kerala_india': 0.014200772621128354,
#   'PortEffectChangeProcess_West Bengal_india': 0.013099999999999992,
#   'PortEffectChangeProcess_Gujarat_india': 0.014299999999999992},
#  {'PortEffectChangeProcess_Maharashtra_india': 0.01590000000000001,
#   'PortEffectChangeProcess_Delhi_india': 0.011332664551305483,
#   'PortEffectChangeProcess_Uttar Pradesh_india': 0.01109999999999999,
#   'PortEffectChangeProcess_Rajasthan_india': 0.01079566054964328,
#   'PortEffectChangeProcess_Kerala_india': 0.015000772621128354,
#   'PortEffectChangeProcess_West Bengal_india': 0.013599999999999992,
#   'PortEffectChangeProcess_Gujarat_india': 0.015099999999999992},
#  {'PortEffectChangeProcess_Maharashtra_india': 0.016800000000000013,
#   'PortEffectChangeProcess_Delhi_india': 0.011332664551305483,
#   'PortEffectChangeProcess_Uttar Pradesh_india': 0.01109999999999999,
#   'PortEffectChangeProcess_Rajasthan_india': 0.01079566054964328,
#   'PortEffectChangeProcess_Kerala_india': 0.015800772621128355,
#   'PortEffectChangeProcess_West Bengal_india': 0.014099999999999993,
#   'PortEffectChangeProcess_Gujarat_india': 0.01589999999999999},
#  {'PortEffectChangeProcess_Maharashtra_india': 0.017700000000000014,
#   'PortEffectChangeProcess_Delhi_india': 0.011332664551305483,
#   'PortEffectChangeProcess_Uttar Pradesh_india': 0.01109999999999999,
#   'PortEffectChangeProcess_Rajasthan_india': 0.01079566054964328,
#   'PortEffectChangeProcess_Kerala_india': 0.016600772621128353,
#   'PortEffectChangeProcess_West Bengal_india': 0.014599999999999993,
#   'PortEffectChangeProcess_Gujarat_india': 0.01669999999999999},
#  {'PortEffectChangeProcess_Maharashtra_india': 0.018600000000000016,
#   'PortEffectChangeProcess_Delhi_india': 0.011332664551305483,
#   'PortEffectChangeProcess_Uttar Pradesh_india': 0.01109999999999999,
#   'PortEffectChangeProcess_Rajasthan_india': 0.01079566054964328,
#   'PortEffectChangeProcess_Kerala_india': 0.017400772621128352,
#   'PortEffectChangeProcess_West Bengal_india': 0.015099999999999994,
#   'PortEffectChangeProcess_Gujarat_india': 0.017499999999999988},
#  {'PortEffectChangeProcess_Maharashtra_india': 0.019500000000000017,
#   'PortEffectChangeProcess_Delhi_india': 0.011332664551305483,
#   'PortEffectChangeProcess_Uttar Pradesh_india': 0.01109999999999999,
#   'PortEffectChangeProcess_Rajasthan_india': 0.01079566054964328,
#   'PortEffectChangeProcess_Kerala_india': 0.01820077262112835,
#   'PortEffectChangeProcess_West Bengal_india': 0.015599999999999994,
#   'PortEffectChangeProcess_Gujarat_india': 0.018299999999999986}]

# %%
# Make a process to increase the number of disease research centers in each locus mentioned in state list if the country has enough GDP and recovered people in that locus. Also increase the recovery rate "C" based on the number of disease research centers. Add a trickle of Healthcare resource stockpile, Sanitation Equipment stockpile and Human Welfare resource. Also use some gdp of the counrry for every building of disease research center
class QuarantineFacilitiesQProcess(ProcessV1):
    RANK = 1
    DOMAIN = (gpe.Country,)

    def __init__(
        self,
        id: str,
        entities,
        status: str,
        country,
        state,
        num_centers,
        gdp_cost_per_center=500,
        health_resource_cost=20,
        sanitation_equipment_cost=20,
    ):
        super().__init__(id, entities, status)
        self.gdp_cost_per_center = gdp_cost_per_center
        self.country = country
        self.num_centers = num_centers
        self.state = state
        self.health_resource_cost = health_resource_cost
        self.sanitation_equipment_cost = sanitation_equipment_cost

    def while_dormant(self, step: int):
        pass

    def while_alive(self, step: int):
        for i, country in enumerate(self.country):
            for locus in self.entities[country].loci:
                if locus.name == self.state[i]:
                    print("Added Quarantine Center in", locus.name)
                    if (
                        self.entities[country].gdp >= self.gdp_cost_per_center * self.num_centers[i] and 
                        self.entities[country].health_resource_stockpile >= self.health_resource_cost * self.num_centers[i]and
                        self.entities[country].sanitation_equipment_stockpile >= self.sanitation_equipment_cost *self.num_centers[i] 
                    ):
                        # Deduct the costs from the country's GDP
                        self.entities[country].gdp -= self.gdp_cost_per_center * self.num_centers[i]
                        self.entities[country].health_resource_stockpile -= self.health_resource_cost * self.num_centers[i]
                        self.entities[country].sanitation_equipment_stockpile -= self.sanitation_equipment_cost * self.num_centers[i]

                        # Increase the number of disease research centers in the locus
                        locus.quarantine_facilities += self.num_centers[i]
                    else:
                        # print("pass1")
                        pass
                if (
                    locus.quarantine_facilities > 0
                ):
                    print(locus.name, "in first if")
                    print(locus.C)
                    print(locus.quarantine_facilities, "before")
                    # Reduce the recovery rate "C" based on the number of disease research centers
                    if locus.quarantine_facilities * 0.0001 <= 0.001:
                        locus.C += locus.quarantine_facilities * 0.0001
                    else:
                        locus.C += 0.001
                    print(locus.C, "after")
                    print(locus.quarantine_facilities, "after")
                    print("***********")

                    # # Add a trickle of Healthcare resource stockpile, Sanitation Equipment stockpile and Human Welfare resource
                    # self.entities[country].health_resource_stockpile += 0.5
                    # self.entities[country].sanitation_equipment_stockpile += 0.5
                    # self.entities[country].human_welfare_resource += 0.2

                # else:
                #     print("inElse")
                #     print(locus.name)
                #     print(locus.recovered, self.min_recovered_people)
                #     print(self.entities[country].disease_research_center)
        # retunr the recovery rate "C" of each locus
        return {
            "QuarantineFacilitiesQProcess"
            + "_"
            + str(locus.name)
            + "_"
            + str(country): locus.C
            for locus in self.entities[country].loci
        }

    def run(self, step: int):
        if self.status == "ALIVE":
            return self.while_alive(step)

# %%
QuarantineFacilities_building_process = QuarantineFacilitiesQProcess(
    "QuarantineFacilitiesQProcess",
    {"india": ind},
    "ALIVE",
    country=["india", "india"],
    state=["West Bengal", "Rajasthan"],
    num_centers=[1, 5],
)

k = []
for i in range(10):
    k.append(QuarantineFacilities_building_process.run(i))
    ind.sync()

k
# Out:
# Maharashtra in first if
# 0.01
# 2 before
# 0.01 after
# 2 after
# ***********
# Delhi in first if
# 0.01
# 2 before
# 0.01 after
# 2 after
# ***********
# Uttar Pradesh in first if
# 0.01
# 2 before
# 0.01 after
# 2 after
# ***********
# Rajasthan in first if
# 0.01
# 2 before
# 0.01 after
# 2 after
# ***********
# Kerala in first if
# 0.01
# 2 before
# 0.01 after
# 2 after
# ***********
# Added Quarantine Center in West Bengal
# West Bengal in first if
# 0.01
# 2 before
# 0.01 after
# 2 after
# ***********
# Gujarat in first if
# 0.01
# 2 before
# 0.01 after
# 2 after
# ***********
# Maharashtra in first if
# 0.01
# 2 before
# 0.01 after
# 2 after
# ***********
# Delhi in first if
# 0.01
# 2 before
# 0.01 after
# 2 after
# ***********
# Uttar Pradesh in first if
# 0.01
# 2 before
# 0.01 after
# 2 after
# ***********
# Added Quarantine Center in Rajasthan
# Rajasthan in first if
# 0.01
# 2 before
# 0.01 after
# 2 after
# ***********
# Kerala in first if
# 0.01
# 2 before
# 0.01 after
# 2 after
# ***********
# West Bengal in first if
# 0.01
# 2 before
# 0.01 after
# 2 after
# ***********
# Gujarat in first if
# 0.01
# 2 before
# 0.01 after
# 2 after
# ***********
# Maharashtra in first if
# 0.0102
# 2 before
# 0.0102 after
# 2 after
# ***********
# Delhi in first if
# 0.0102
# 2 before
# 0.0102 after
# 2 after
# ***********
# Uttar Pradesh in first if
# 0.0102
# 2 before
# 0.0102 after
# 2 after
# ***********
# Rajasthan in first if
# 0.0102
# 7 before
# 0.0102 after
# 7 after
# ***********
# Kerala in first if
# 0.0102
# 2 before
# 0.0102 after
# 2 after
# ***********
# Added Quarantine Center in West Bengal
# West Bengal in first if
# 0.0102
# 3 before
# 0.0102 after
# 3 after
# ***********
# Gujarat in first if
# 0.0102
# 2 before
# 0.0102 after
# 2 after
# ***********
# Maharashtra in first if
# 0.0102
# 2 before
# 0.0102 after
# 2 after
# ***********
# Delhi in first if
# 0.0102
# 2 before
# 0.0102 after
# 2 after
# ***********
# Uttar Pradesh in first if
# 0.0102
# 2 before
# 0.0102 after
# 2 after
# ***********
# Added Quarantine Center in Rajasthan
# Rajasthan in first if
# 0.0102
# 7 before
# 0.0102 after
# 7 after
# ***********
# Kerala in first if
# 0.0102
# 2 before
# 0.0102 after
# 2 after
# ***********
# West Bengal in first if
# 0.0102
# 3 before
# 0.0102 after
# 3 after
# ***********
# Gujarat in first if
# 0.0102
# 2 before
# 0.0102 after
# 2 after
# ***********
# Maharashtra in first if
# 0.010400000000000001
# 2 before
# 0.010400000000000001 after
# 2 after
# ***********
# Delhi in first if
# 0.010400000000000001
# 2 before
# 0.010400000000000001 after
# 2 after
# ***********
# Uttar Pradesh in first if
# 0.010400000000000001
# 2 before
# 0.010400000000000001 after
# 2 after
# ***********
# Rajasthan in first if
# 0.0109
# 12 before
# 0.0109 after
# 12 after
# ***********
# Kerala in first if
# 0.010400000000000001
# 2 before
# 0.010400000000000001 after
# 2 after
# ***********
# Added Quarantine Center in West Bengal
# West Bengal in first if
# 0.0105
# 4 before
# 0.0105 after
# 4 after
# ***********
# Gujarat in first if
# 0.010400000000000001
# 2 before
# 0.010400000000000001 after
# 2 after
# ***********
# Maharashtra in first if
# 0.010400000000000001
# 2 before
# 0.010400000000000001 after
# 2 after
# ***********
# Delhi in first if
# 0.010400000000000001
# 2 before
# 0.010400000000000001 after
# 2 after
# ***********
# Uttar Pradesh in first if
# 0.010400000000000001
# 2 before
# 0.010400000000000001 after
# 2 after
# ***********
# Added Quarantine Center in Rajasthan
# Rajasthan in first if
# 0.0109
# 12 before
# 0.0109 after
# 12 after
# ***********
# Kerala in first if
# 0.010400000000000001
# 2 before
# 0.010400000000000001 after
# 2 after
# ***********
# West Bengal in first if
# 0.0105
# 4 before
# 0.0105 after
# 4 after
# ***********
# Gujarat in first if
# 0.010400000000000001
# 2 before
# 0.010400000000000001 after
# 2 after
# ***********
# Maharashtra in first if
# 0.010600000000000002
# 2 before
# 0.010600000000000002 after
# 2 after
# ***********
# Delhi in first if
# 0.010600000000000002
# 2 before
# 0.010600000000000002 after
# 2 after
# ***********
# Uttar Pradesh in first if
# 0.010600000000000002
# 2 before
# 0.010600000000000002 after
# 2 after
# ***********
# Rajasthan in first if
# 0.0119
# 17 before
# 0.0119 after
# 17 after
# ***********
# Kerala in first if
# 0.010600000000000002
# 2 before
# 0.010600000000000002 after
# 2 after
# ***********
# Added Quarantine Center in West Bengal
# West Bengal in first if
# 0.0109
# 5 before
# 0.0109 after
# 5 after
# ***********
# Gujarat in first if
# 0.010600000000000002
# 2 before
# 0.010600000000000002 after
# 2 after
# ***********
# Maharashtra in first if
# 0.010600000000000002
# 2 before
# 0.010600000000000002 after
# 2 after
# ***********
# Delhi in first if
# 0.010600000000000002
# 2 before
# 0.010600000000000002 after
# 2 after
# ***********
# Uttar Pradesh in first if
# 0.010600000000000002
# 2 before
# 0.010600000000000002 after
# 2 after
# ***********
# Added Quarantine Center in Rajasthan
# Rajasthan in first if
# 0.0119
# 17 before
# 0.0119 after
# 17 after
# ***********
# Kerala in first if
# 0.010600000000000002
# 2 before
# 0.010600000000000002 after
# 2 after
# ***********
# West Bengal in first if
# 0.0109
# 5 before
# 0.0109 after
# 5 after
# ***********
# Gujarat in first if
# 0.010600000000000002
# 2 before
# 0.010600000000000002 after
# 2 after
# ***********
# Maharashtra in first if
# 0.010800000000000002
# 2 before
# 0.010800000000000002 after
# 2 after
# ***********
# Delhi in first if
# 0.010800000000000002
# 2 before
# 0.010800000000000002 after
# 2 after
# ***********
# Uttar Pradesh in first if
# 0.010800000000000002
# 2 before
# 0.010800000000000002 after
# 2 after
# ***********
# Rajasthan in first if
# 0.012900000000000002
# 22 before
# 0.012900000000000002 after
# 22 after
# ***********
# Kerala in first if
# 0.010800000000000002
# 2 before
# 0.010800000000000002 after
# 2 after
# ***********
# Added Quarantine Center in West Bengal
# West Bengal in first if
# 0.0114
# 6 before
# 0.0114 after
# 6 after
# ***********
# Gujarat in first if
# 0.010800000000000002
# 2 before
# 0.010800000000000002 after
# 2 after
# ***********
# Maharashtra in first if
# 0.010800000000000002
# 2 before
# 0.010800000000000002 after
# 2 after
# ***********
# Delhi in first if
# 0.010800000000000002
# 2 before
# 0.010800000000000002 after
# 2 after
# ***********
# Uttar Pradesh in first if
# 0.010800000000000002
# 2 before
# 0.010800000000000002 after
# 2 after
# ***********
# Added Quarantine Center in Rajasthan
# Rajasthan in first if
# 0.012900000000000002
# 22 before
# 0.012900000000000002 after
# 22 after
# ***********
# Kerala in first if
# 0.010800000000000002
# 2 before
# 0.010800000000000002 after
# 2 after
# ***********
# West Bengal in first if
# 0.0114
# 6 before
# 0.0114 after
# 6 after
# ***********
# Gujarat in first if
# 0.010800000000000002
# 2 before
# 0.010800000000000002 after
# 2 after
# ***********
# Maharashtra in first if
# 0.011000000000000003
# 2 before
# 0.011000000000000003 after
# 2 after
# ***********
# Delhi in first if
# 0.011000000000000003
# 2 before
# 0.011000000000000003 after
# 2 after
# ***********
# Uttar Pradesh in first if
# 0.011000000000000003
# 2 before
# 0.011000000000000003 after
# 2 after
# ***********
# Rajasthan in first if
# 0.013900000000000003
# 27 before
# 0.013900000000000003 after
# 27 after
# ***********
# Kerala in first if
# 0.011000000000000003
# 2 before
# 0.011000000000000003 after
# 2 after
# ***********
# Added Quarantine Center in West Bengal
# West Bengal in first if
# 0.012
# 7 before
# 0.012 after
# 7 after
# ***********
# Gujarat in first if
# 0.011000000000000003
# 2 before
# 0.011000000000000003 after
# 2 after
# ***********
# Maharashtra in first if
# 0.011000000000000003
# 2 before
# 0.011000000000000003 after
# 2 after
# ***********
# Delhi in first if
# 0.011000000000000003
# 2 before
# 0.011000000000000003 after
# 2 after
# ***********
# Uttar Pradesh in first if
# 0.011000000000000003
# 2 before
# 0.011000000000000003 after
# 2 after
# ***********
# Added Quarantine Center in Rajasthan
# Rajasthan in first if
# 0.013900000000000003
# 27 before
# 0.013900000000000003 after
# 27 after
# ***********
# Kerala in first if
# 0.011000000000000003
# 2 before
# 0.011000000000000003 after
# 2 after
# ***********
# West Bengal in first if
# 0.012
# 7 before
# 0.012 after
# 7 after
# ***********
# Gujarat in first if
# 0.011000000000000003
# 2 before
# 0.011000000000000003 after
# 2 after
# ***********
# Maharashtra in first if
# 0.011200000000000003
# 2 before
# 0.011200000000000003 after
# 2 after
# ***********
# Delhi in first if
# 0.011200000000000003
# 2 before
# 0.011200000000000003 after
# 2 after
# ***********
# Uttar Pradesh in first if
# 0.011200000000000003
# 2 before
# 0.011200000000000003 after
# 2 after
# ***********
# Rajasthan in first if
# 0.014900000000000004
# 32 before
# 0.014900000000000004 after
# 32 after
# ***********
# Kerala in first if
# 0.011200000000000003
# 2 before
# 0.011200000000000003 after
# 2 after
# ***********
# Added Quarantine Center in West Bengal
# West Bengal in first if
# 0.0127
# 8 before
# 0.0127 after
# 8 after
# ***********
# Gujarat in first if
# 0.011200000000000003
# 2 before
# 0.011200000000000003 after
# 2 after
# ***********
# Maharashtra in first if
# 0.011200000000000003
# 2 before
# 0.011200000000000003 after
# 2 after
# ***********
# Delhi in first if
# 0.011200000000000003
# 2 before
# 0.011200000000000003 after
# 2 after
# ***********
# Uttar Pradesh in first if
# 0.011200000000000003
# 2 before
# 0.011200000000000003 after
# 2 after
# ***********
# Added Quarantine Center in Rajasthan
# Rajasthan in first if
# 0.014900000000000004
# 32 before
# 0.014900000000000004 after
# 32 after
# ***********
# Kerala in first if
# 0.011200000000000003
# 2 before
# 0.011200000000000003 after
# 2 after
# ***********
# West Bengal in first if
# 0.0127
# 8 before
# 0.0127 after
# 8 after
# ***********
# Gujarat in first if
# 0.011200000000000003
# 2 before
# 0.011200000000000003 after
# 2 after
# ***********
# Maharashtra in first if
# 0.011400000000000004
# 2 before
# 0.011400000000000004 after
# 2 after
# ***********
# Delhi in first if
# 0.011400000000000004
# 2 before
# 0.011400000000000004 after
# 2 after
# ***********
# Uttar Pradesh in first if
# 0.011400000000000004
# 2 before
# 0.011400000000000004 after
# 2 after
# ***********
# Rajasthan in first if
# 0.015900000000000004
# 37 before
# 0.015900000000000004 after
# 37 after
# ***********
# Kerala in first if
# 0.011400000000000004
# 2 before
# 0.011400000000000004 after
# 2 after
# ***********
# Added Quarantine Center in West Bengal
# West Bengal in first if
# 0.0135
# 9 before
# 0.0135 after
# 9 after
# ***********
# Gujarat in first if
# 0.011400000000000004
# 2 before
# 0.011400000000000004 after
# 2 after
# ***********
# Maharashtra in first if
# 0.011400000000000004
# 2 before
# 0.011400000000000004 after
# 2 after
# ***********
# Delhi in first if
# 0.011400000000000004
# 2 before
# 0.011400000000000004 after
# 2 after
# ***********
# Uttar Pradesh in first if
# 0.011400000000000004
# 2 before
# 0.011400000000000004 after
# 2 after
# ***********
# Added Quarantine Center in Rajasthan
# Rajasthan in first if
# 0.015900000000000004
# 37 before
# 0.015900000000000004 after
# 37 after
# ***********
# Kerala in first if
# 0.011400000000000004
# 2 before
# 0.011400000000000004 after
# 2 after
# ***********
# West Bengal in first if
# 0.0135
# 9 before
# 0.0135 after
# 9 after
# ***********
# Gujarat in first if
# 0.011400000000000004
# 2 before
# 0.011400000000000004 after
# 2 after
# ***********
# Maharashtra in first if
# 0.011600000000000004
# 2 before
# 0.011600000000000004 after
# 2 after
# ***********
# Delhi in first if
# 0.011600000000000004
# 2 before
# 0.011600000000000004 after
# 2 after
# ***********
# Uttar Pradesh in first if
# 0.011600000000000004
# 2 before
# 0.011600000000000004 after
# 2 after
# ***********
# Rajasthan in first if
# 0.016900000000000005
# 42 before
# 0.016900000000000005 after
# 42 after
# ***********
# Kerala in first if
# 0.011600000000000004
# 2 before
# 0.011600000000000004 after
# 2 after
# ***********
# Added Quarantine Center in West Bengal
# West Bengal in first if
# 0.0144
# 10 before
# 0.0144 after
# 10 after
# ***********
# Gujarat in first if
# 0.011600000000000004
# 2 before
# 0.011600000000000004 after
# 2 after
# ***********
# Maharashtra in first if
# 0.011600000000000004
# 2 before
# 0.011600000000000004 after
# 2 after
# ***********
# Delhi in first if
# 0.011600000000000004
# 2 before
# 0.011600000000000004 after
# 2 after
# ***********
# Uttar Pradesh in first if
# 0.011600000000000004
# 2 before
# 0.011600000000000004 after
# 2 after
# ***********
# Added Quarantine Center in Rajasthan
# Rajasthan in first if
# 0.016900000000000005
# 42 before
# 0.016900000000000005 after
# 42 after
# ***********
# Kerala in first if
# 0.011600000000000004
# 2 before
# 0.011600000000000004 after
# 2 after
# ***********
# West Bengal in first if
# 0.0144
# 10 before
# 0.0144 after
# 10 after
# ***********
# Gujarat in first if
# 0.011600000000000004
# 2 before
# 0.011600000000000004 after
# 2 after
# ***********
# Maharashtra in first if
# 0.011800000000000005
# 2 before
# 0.011800000000000005 after
# 2 after
# ***********
# Delhi in first if
# 0.011800000000000005
# 2 before
# 0.011800000000000005 after
# 2 after
# ***********
# Uttar Pradesh in first if
# 0.011800000000000005
# 2 before
# 0.011800000000000005 after
# 2 after
# ***********
# Rajasthan in first if
# 0.017900000000000006
# 47 before
# 0.017900000000000006 after
# 47 after
# ***********
# Kerala in first if
# 0.011800000000000005
# 2 before
# 0.011800000000000005 after
# 2 after
# ***********
# Added Quarantine Center in West Bengal
# West Bengal in first if
# 0.0154
# 11 before
# 0.0154 after
# 11 after
# ***********
# Gujarat in first if
# 0.011800000000000005
# 2 before
# 0.011800000000000005 after
# 2 after
# ***********
# Maharashtra in first if
# 0.011800000000000005
# 2 before
# 0.011800000000000005 after
# 2 after
# ***********
# Delhi in first if
# 0.011800000000000005
# 2 before
# 0.011800000000000005 after
# 2 after
# ***********
# Uttar Pradesh in first if
# 0.011800000000000005
# 2 before
# 0.011800000000000005 after
# 2 after
# ***********
# Added Quarantine Center in Rajasthan
# Rajasthan in first if
# 0.017900000000000006
# 47 before
# 0.017900000000000006 after
# 47 after
# ***********
# Kerala in first if
# 0.011800000000000005
# 2 before
# 0.011800000000000005 after
# 2 after
# ***********
# West Bengal in first if
# 0.0154
# 11 before
# 0.0154 after
# 11 after
# ***********
# Gujarat in first if
# 0.011800000000000005
# 2 before
# 0.011800000000000005 after
# 2 after
# ***********
# [{'QuarantineFacilitiesQProcess_Maharashtra_india': 0.01,
#   'QuarantineFacilitiesQProcess_Delhi_india': 0.01,
#   'QuarantineFacilitiesQProcess_Uttar Pradesh_india': 0.01,
#   'QuarantineFacilitiesQProcess_Rajasthan_india': 0.01,
#   'QuarantineFacilitiesQProcess_Kerala_india': 0.01,
#   'QuarantineFacilitiesQProcess_West Bengal_india': 0.01,
#   'QuarantineFacilitiesQProcess_Gujarat_india': 0.01},
#  {'QuarantineFacilitiesQProcess_Maharashtra_india': 0.0102,
#   'QuarantineFacilitiesQProcess_Delhi_india': 0.0102,
#   'QuarantineFacilitiesQProcess_Uttar Pradesh_india': 0.0102,
#   'QuarantineFacilitiesQProcess_Rajasthan_india': 0.0102,
#   'QuarantineFacilitiesQProcess_Kerala_india': 0.0102,
#   'QuarantineFacilitiesQProcess_West Bengal_india': 0.0102,
#   'QuarantineFacilitiesQProcess_Gujarat_india': 0.0102},
#  {'QuarantineFacilitiesQProcess_Maharashtra_india': 0.010400000000000001,
#   'QuarantineFacilitiesQProcess_Delhi_india': 0.010400000000000001,
#   'QuarantineFacilitiesQProcess_Uttar Pradesh_india': 0.010400000000000001,
#   'QuarantineFacilitiesQProcess_Rajasthan_india': 0.0109,
#   'QuarantineFacilitiesQProcess_Kerala_india': 0.010400000000000001,
#   'QuarantineFacilitiesQProcess_West Bengal_india': 0.0105,
#   'QuarantineFacilitiesQProcess_Gujarat_india': 0.010400000000000001},
#  {'QuarantineFacilitiesQProcess_Maharashtra_india': 0.010600000000000002,
#   'QuarantineFacilitiesQProcess_Delhi_india': 0.010600000000000002,
#   'QuarantineFacilitiesQProcess_Uttar Pradesh_india': 0.010600000000000002,
#   'QuarantineFacilitiesQProcess_Rajasthan_india': 0.0119,
#   'QuarantineFacilitiesQProcess_Kerala_india': 0.010600000000000002,
#   'QuarantineFacilitiesQProcess_West Bengal_india': 0.0109,
#   'QuarantineFacilitiesQProcess_Gujarat_india': 0.010600000000000002},
#  {'QuarantineFacilitiesQProcess_Maharashtra_india': 0.010800000000000002,
#   'QuarantineFacilitiesQProcess_Delhi_india': 0.010800000000000002,
#   'QuarantineFacilitiesQProcess_Uttar Pradesh_india': 0.010800000000000002,
#   'QuarantineFacilitiesQProcess_Rajasthan_india': 0.012900000000000002,
#   'QuarantineFacilitiesQProcess_Kerala_india': 0.010800000000000002,
#   'QuarantineFacilitiesQProcess_West Bengal_india': 0.0114,
#   'QuarantineFacilitiesQProcess_Gujarat_india': 0.010800000000000002},
#  {'QuarantineFacilitiesQProcess_Maharashtra_india': 0.011000000000000003,
#   'QuarantineFacilitiesQProcess_Delhi_india': 0.011000000000000003,
#   'QuarantineFacilitiesQProcess_Uttar Pradesh_india': 0.011000000000000003,
#   'QuarantineFacilitiesQProcess_Rajasthan_india': 0.013900000000000003,
#   'QuarantineFacilitiesQProcess_Kerala_india': 0.011000000000000003,
#   'QuarantineFacilitiesQProcess_West Bengal_india': 0.012,
#   'QuarantineFacilitiesQProcess_Gujarat_india': 0.011000000000000003},
#  {'QuarantineFacilitiesQProcess_Maharashtra_india': 0.011200000000000003,
#   'QuarantineFacilitiesQProcess_Delhi_india': 0.011200000000000003,
#   'QuarantineFacilitiesQProcess_Uttar Pradesh_india': 0.011200000000000003,
#   'QuarantineFacilitiesQProcess_Rajasthan_india': 0.014900000000000004,
#   'QuarantineFacilitiesQProcess_Kerala_india': 0.011200000000000003,
#   'QuarantineFacilitiesQProcess_West Bengal_india': 0.0127,
#   'QuarantineFacilitiesQProcess_Gujarat_india': 0.011200000000000003},
#  {'QuarantineFacilitiesQProcess_Maharashtra_india': 0.011400000000000004,
#   'QuarantineFacilitiesQProcess_Delhi_india': 0.011400000000000004,
#   'QuarantineFacilitiesQProcess_Uttar Pradesh_india': 0.011400000000000004,
#   'QuarantineFacilitiesQProcess_Rajasthan_india': 0.015900000000000004,
#   'QuarantineFacilitiesQProcess_Kerala_india': 0.011400000000000004,
#   'QuarantineFacilitiesQProcess_West Bengal_india': 0.0135,
#   'QuarantineFacilitiesQProcess_Gujarat_india': 0.011400000000000004},
#  {'QuarantineFacilitiesQProcess_Maharashtra_india': 0.011600000000000004,
#   'QuarantineFacilitiesQProcess_Delhi_india': 0.011600000000000004,
#   'QuarantineFacilitiesQProcess_Uttar Pradesh_india': 0.011600000000000004,
#   'QuarantineFacilitiesQProcess_Rajasthan_india': 0.016900000000000005,
#   'QuarantineFacilitiesQProcess_Kerala_india': 0.011600000000000004,
#   'QuarantineFacilitiesQProcess_West Bengal_india': 0.0144,
#   'QuarantineFacilitiesQProcess_Gujarat_india': 0.011600000000000004},
#  {'QuarantineFacilitiesQProcess_Maharashtra_india': 0.011800000000000005,
#   'QuarantineFacilitiesQProcess_Delhi_india': 0.011800000000000005,
#   'QuarantineFacilitiesQProcess_Uttar Pradesh_india': 0.011800000000000005,
#   'QuarantineFacilitiesQProcess_Rajasthan_india': 0.017900000000000006,
#   'QuarantineFacilitiesQProcess_Kerala_india': 0.011800000000000005,
#   'QuarantineFacilitiesQProcess_West Bengal_india': 0.0154,
#   'QuarantineFacilitiesQProcess_Gujarat_india': 0.011800000000000005}]

# %% [markdown]
# ### ONLY INCREASE in B from Machine processs

# %% [markdown]
# Run this after all implementation processes

# %%
# Make a process increase B due to Susceptable population density, Baseline Infection rate, Cleanliness index in each of loci of all countries in entities
class IncreaseBProcess(ProcessV1):
    RANK = 1
    DOMAIN = (gpe.Country,)

    def __init__(self, id: str, entities, status: str, infected_country: str):
        super().__init__(id, entities, status)
        self.infected_country = infected_country

    def while_dormant(self, step: int):
        pass

    def calculate_increase_factor(
        self, susceptible_population_density, baseline_infection_rate, cleanliness_index
    ):
        increase_factor = (
            susceptible_population_density
            * baseline_infection_rate
            * (1 - cleanliness_index)
        )
        return increase_factor

    def while_alive(self, step: int):
        for country in self.entities:
            if country != self.infected_country:
                for locus in country.loci:
                    susceptible_population_density = locus.susceptible / (
                        max_living_population * locus.area
                    )
                    increase_factor = self.calculate_increase_factor(
                        susceptible_population_density,
                        baseline_infection_rate,
                        self.cleanliness_index,
                    )
                    if locus.B + increase_factor <= 0.0005:
                        locus.B += increase_factor
                    else:
                        locus.B = 0.0005

                    # Move locus.B percent of people from susceptible to infected
                    if locus.susceptible > 0:
                        locus.infected += locus.susceptible * locus.B
                        locus.susceptible -= locus.susceptible * locus.B
                    else:
                        locus.susceptible = 0

            else:
                for locus in country.loci:
                    susceptible_population_density = locus.susceptible / (
                        max_living_population * locus.area
                    )
                    increase_factor = self.calculate_increase_factor(
                        susceptible_population_density,
                        epidemic_increased_infection_rate,
                        self.cleanliness_index,
                    )
                    if locus.B + increase_factor <= 0.0009:
                        locus.B += increase_factor
                    else:
                        locus.B = 0.0009

                    if locus.susceptible > 0:
                        locus.infected += locus.susceptible * locus.B
                        locus.susceptible -= locus.susceptible * locus.B
                    else:
                        locus.susceptible = 0

        # return number of susceptable, infected and recovered people in each locus
        return {
            "IncreaseBProcess"
            + "_"
            + str(locus.name)
            + "_"
            + str(country): [
                locus.susceptible,
                locus.infected,
                locus.recovered,
                locus.dead,
            ]
            for locus in self.entities[country].loci
        }

    def run(self):
        if self.status == "ALIVE":
            return self.while_active()

# %% [markdown]
# ### **C PARAMETER**

# %% [markdown]
# #### General Hospital increase value (user input)

# %%
ind = gpe.Country(**ind_config)

# %%
# Make increase number of genreal hospitals in each locus mentioned in state list if the country has enough GDP and recovered people in that locus. Also increase the recovery rate "C" based on the number of hospitals in that locus and population density (if more then increase in C is lower)

class GeneralHospitalBuildingProcess(ProcessV1):
    RANK = 1
    DOMAIN = (gpe.Country,)

    def __init__(
        self,
        id: str,
        entities,
        status: str,
        country,
        state,
        num_hospitals,
        gdp_cost_per_hospital=500,
        min_recovered_people=50,
    ):
        super().__init__(id, entities, status)
        self.gdp_cost_per_hospital = gdp_cost_per_hospital
        self.min_recovered_people = min_recovered_people
        self.num_hospitals = num_hospitals
        self.country = country
        self.num_hospitals = num_hospitals
        self.state = state

    def while_dormant(self, step: int):
        pass

    def while_alive(self, step: int):
        for i, country in enumerate(self.country):
            for locus in self.entities[country].loci:
                if locus.name == self.state[i]:
                    if (
                        self.entities[country].gdp >= self.gdp_cost_per_hospital
                        and locus.recovered >= self.min_recovered_people
                    ):
                        # Deduct the costs from the country's GDP
                        self.entities[country].gdp -= self.gdp_cost_per_hospital * self.num_hospitals[i]

                        # Increase the number of hospitals in the locus
                        locus.general_hospitals += self.num_hospitals[i]
                    else:
                        print("pass1")
                        pass
                if locus.recovered >= self.min_recovered_people and locus.general_hospitals > 0:
                    # Reduce the recovery rate "C" based on the number of hospitals
                    if  locus.general_hospitals * 0.0005 <= 0.001:
                        locus.C += locus.general_hospitals * 0.005
                    else:
                        locus.C += 0.001


        return {
            "GeneralHospitalBuildingProcess"
            + "_"
            + str(locus.name)
            + "_"
            + str(country): locus.C
            for locus in self.entities[country].loci
        }

    def run(self, step: int):
        if self.status == "ALIVE":
            return self.while_alive(step)

# %%
general_hospital_building_process = GeneralHospitalBuildingProcess(
    "GeneralHospitalBuildingProcess",
    {"india": ind},
    "ALIVE",
    country=["india", "india"],
    state=["Delhi", "Gujarat"],
    num_hospitals=[1, 5],
)

k = []
for i in range(100):
    k.append(general_hospital_building_process.run(i))
    ind.sync()

k
# Out:
# [{'GeneralHospitalBuildingProcess_Maharashtra_india': 0.01,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.01,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.01,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.01,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.01,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.01,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.01},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.011,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.011,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.011,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.011,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.011,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.011,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.015},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.012,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.012,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.012,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.012,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.012,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.012,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.016},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.013000000000000001,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.013000000000000001,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.013000000000000001,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.013000000000000001,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.013000000000000001,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.013000000000000001,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.017},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.014000000000000002,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.014000000000000002,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.014000000000000002,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.014000000000000002,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.014000000000000002,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.014000000000000002,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.018000000000000002},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.015000000000000003,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.015000000000000003,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.015000000000000003,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.015000000000000003,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.015000000000000003,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.015000000000000003,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.019000000000000003},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.016000000000000004,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.016000000000000004,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.016000000000000004,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.016000000000000004,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.016000000000000004,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.016000000000000004,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.020000000000000004},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.017000000000000005,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.017000000000000005,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.017000000000000005,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.017000000000000005,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.017000000000000005,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.017000000000000005,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.021000000000000005},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.018000000000000006,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.018000000000000006,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.018000000000000006,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.018000000000000006,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.018000000000000006,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.018000000000000006,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.022000000000000006},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.019000000000000006,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.019000000000000006,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.019000000000000006,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.019000000000000006,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.019000000000000006,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.019000000000000006,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.023000000000000007},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.020000000000000007,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.020000000000000007,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.020000000000000007,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.020000000000000007,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.020000000000000007,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.020000000000000007,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.024000000000000007},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.021000000000000008,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.021000000000000008,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.021000000000000008,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.021000000000000008,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.021000000000000008,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.021000000000000008,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.02500000000000001},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.02200000000000001,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.02200000000000001,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.02200000000000001,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.02200000000000001,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.02200000000000001,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.02200000000000001,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.02600000000000001},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.02300000000000001,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.02300000000000001,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.02300000000000001,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.02300000000000001,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.02300000000000001,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.02300000000000001,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.02700000000000001},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.02400000000000001,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.02400000000000001,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.02400000000000001,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.02400000000000001,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.02400000000000001,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.02400000000000001,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.02800000000000001},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.025000000000000012,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.025000000000000012,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.025000000000000012,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.025000000000000012,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.025000000000000012,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.025000000000000012,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.029000000000000012},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.026000000000000013,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.026000000000000013,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.026000000000000013,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.026000000000000013,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.026000000000000013,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.026000000000000013,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.030000000000000013},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.027000000000000014,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.027000000000000014,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.027000000000000014,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.027000000000000014,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.027000000000000014,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.027000000000000014,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.031000000000000014},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.028000000000000014,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.028000000000000014,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.028000000000000014,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.028000000000000014,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.028000000000000014,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.028000000000000014,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.032000000000000015},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.029000000000000015,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.029000000000000015,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.029000000000000015,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.029000000000000015,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.029000000000000015,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.029000000000000015,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.033000000000000015},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.030000000000000016,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.030000000000000016,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.030000000000000016,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.030000000000000016,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.030000000000000016,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.030000000000000016,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.034000000000000016},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.031000000000000017,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.031000000000000017,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.031000000000000017,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.031000000000000017,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.031000000000000017,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.031000000000000017,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.03500000000000002},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.032000000000000015,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.032000000000000015,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.032000000000000015,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.032000000000000015,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.032000000000000015,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.032000000000000015,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.03600000000000002},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.033000000000000015,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.033000000000000015,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.033000000000000015,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.033000000000000015,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.033000000000000015,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.033000000000000015,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.03700000000000002},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.034000000000000016,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.034000000000000016,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.034000000000000016,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.034000000000000016,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.034000000000000016,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.034000000000000016,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.03800000000000002},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.03500000000000002,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.03500000000000002,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.03500000000000002,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.03500000000000002,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.03500000000000002,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.03500000000000002,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.03900000000000002},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.03600000000000002,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.03600000000000002,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.03600000000000002,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.03600000000000002,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.03600000000000002,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.03600000000000002,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.04000000000000002},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.03700000000000002,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.03700000000000002,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.03700000000000002,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.03700000000000002,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.03700000000000002,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.03700000000000002,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.04100000000000002},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.03800000000000002,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.03800000000000002,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.03800000000000002,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.03800000000000002,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.03800000000000002,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.03800000000000002,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.04200000000000002},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.03900000000000002,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.03900000000000002,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.03900000000000002,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.03900000000000002,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.03900000000000002,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.03900000000000002,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.043000000000000024},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.04000000000000002,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.04000000000000002,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.04000000000000002,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.04000000000000002,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.04000000000000002,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.04000000000000002,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.044000000000000025},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.04100000000000002,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.04100000000000002,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.04100000000000002,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.04100000000000002,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.04100000000000002,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.04100000000000002,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.045000000000000026},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.04200000000000002,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.04200000000000002,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.04200000000000002,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.04200000000000002,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.04200000000000002,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.04200000000000002,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.04600000000000003},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.043000000000000024,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.043000000000000024,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.043000000000000024,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.043000000000000024,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.043000000000000024,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.043000000000000024,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.04700000000000003},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.044000000000000025,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.044000000000000025,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.044000000000000025,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.044000000000000025,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.044000000000000025,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.044000000000000025,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.04800000000000003},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.045000000000000026,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.045000000000000026,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.045000000000000026,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.045000000000000026,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.045000000000000026,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.045000000000000026,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.04900000000000003},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.04600000000000003,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.04600000000000003,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.04600000000000003,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.04600000000000003,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.04600000000000003,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.04600000000000003,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.05000000000000003},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.04700000000000003,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.04700000000000003,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.04700000000000003,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.04700000000000003,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.04700000000000003,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.04700000000000003,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.05100000000000003},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.04800000000000003,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.04800000000000003,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.04800000000000003,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.04800000000000003,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.04800000000000003,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.04800000000000003,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.05200000000000003},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.04900000000000003,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.04900000000000003,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.04900000000000003,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.04900000000000003,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.04900000000000003,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.04900000000000003,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.05300000000000003},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.05000000000000003,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.05000000000000003,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.05000000000000003,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.05000000000000003,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.05000000000000003,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.05000000000000003,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.054000000000000034},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.05100000000000003,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.05100000000000003,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.05100000000000003,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.05100000000000003,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.05100000000000003,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.05100000000000003,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.055000000000000035},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.05200000000000003,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.05200000000000003,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.05200000000000003,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.05200000000000003,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.05200000000000003,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.05200000000000003,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.056000000000000036},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.05300000000000003,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.05300000000000003,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.05300000000000003,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.05300000000000003,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.05300000000000003,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.05300000000000003,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.05700000000000004},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.054000000000000034,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.054000000000000034,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.054000000000000034,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.054000000000000034,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.054000000000000034,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.054000000000000034,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.05800000000000004},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.055000000000000035,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.055000000000000035,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.055000000000000035,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.055000000000000035,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.055000000000000035,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.055000000000000035,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.05900000000000004},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.056000000000000036,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.056000000000000036,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.056000000000000036,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.056000000000000036,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.056000000000000036,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.056000000000000036,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.06000000000000004},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.05700000000000004,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.05700000000000004,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.05700000000000004,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.05700000000000004,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.05700000000000004,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.05700000000000004,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.06100000000000004},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.05800000000000004,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.05800000000000004,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.05800000000000004,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.05800000000000004,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.05800000000000004,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.05800000000000004,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.06200000000000004},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.05900000000000004,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.05900000000000004,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.05900000000000004,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.05900000000000004,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.05900000000000004,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.05900000000000004,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.06300000000000004},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.06000000000000004,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.06000000000000004,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.06000000000000004,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.06000000000000004,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.06000000000000004,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.06000000000000004,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.06400000000000004},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.06100000000000004,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.06100000000000004,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.06100000000000004,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.06100000000000004,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.06100000000000004,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.06100000000000004,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.06500000000000004},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.06200000000000004,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.06200000000000004,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.06200000000000004,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.06200000000000004,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.06200000000000004,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.06200000000000004,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.06600000000000004},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.06300000000000004,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.06300000000000004,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.06300000000000004,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.06300000000000004,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.06300000000000004,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.06300000000000004,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.06700000000000005},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.06400000000000004,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.06400000000000004,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.06400000000000004,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.06400000000000004,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.06400000000000004,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.06400000000000004,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.06800000000000005},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.06500000000000004,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.06500000000000004,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.06500000000000004,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.06500000000000004,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.06500000000000004,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.06500000000000004,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.06900000000000005},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.06600000000000004,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.06600000000000004,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.06600000000000004,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.06600000000000004,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.06600000000000004,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.06600000000000004,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.07000000000000005},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.06700000000000005,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.06700000000000005,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.06700000000000005,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.06700000000000005,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.06700000000000005,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.06700000000000005,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.07100000000000005},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.06800000000000005,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.06800000000000005,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.06800000000000005,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.06800000000000005,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.06800000000000005,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.06800000000000005,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.07200000000000005},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.06900000000000005,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.06900000000000005,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.06900000000000005,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.06900000000000005,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.06900000000000005,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.06900000000000005,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.07300000000000005},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.07000000000000005,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.07000000000000005,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.07000000000000005,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.07000000000000005,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.07000000000000005,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.07000000000000005,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.07400000000000005},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.07100000000000005,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.07100000000000005,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.07100000000000005,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.07100000000000005,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.07100000000000005,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.07100000000000005,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.07500000000000005},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.07200000000000005,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.07200000000000005,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.07200000000000005,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.07200000000000005,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.07200000000000005,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.07200000000000005,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.07600000000000005},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.07300000000000005,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.07300000000000005,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.07300000000000005,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.07300000000000005,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.07300000000000005,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.07300000000000005,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.07700000000000005},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.07400000000000005,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.07400000000000005,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.07400000000000005,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.07400000000000005,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.07400000000000005,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.07400000000000005,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.07800000000000006},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.07500000000000005,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.07500000000000005,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.07500000000000005,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.07500000000000005,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.07500000000000005,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.07500000000000005,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.07900000000000006},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.07600000000000005,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.07600000000000005,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.07600000000000005,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.07600000000000005,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.07600000000000005,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.07600000000000005,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.08000000000000006},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.07700000000000005,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.07700000000000005,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.07700000000000005,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.07700000000000005,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.07700000000000005,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.07700000000000005,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.08100000000000006},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.07800000000000006,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.07800000000000006,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.07800000000000006,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.07800000000000006,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.07800000000000006,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.07800000000000006,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.08200000000000006},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.07900000000000006,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.07900000000000006,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.07900000000000006,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.07900000000000006,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.07900000000000006,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.07900000000000006,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.08300000000000006},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.08000000000000006,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.08000000000000006,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.08000000000000006,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.08000000000000006,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.08000000000000006,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.08000000000000006,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.08400000000000006},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.08100000000000006,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.08100000000000006,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.08100000000000006,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.08100000000000006,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.08100000000000006,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.08100000000000006,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.08500000000000006},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.08200000000000006,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.08200000000000006,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.08200000000000006,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.08200000000000006,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.08200000000000006,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.08200000000000006,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.08600000000000006},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.08300000000000006,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.08300000000000006,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.08300000000000006,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.08300000000000006,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.08300000000000006,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.08300000000000006,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.08700000000000006},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.08400000000000006,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.08400000000000006,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.08400000000000006,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.08400000000000006,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.08400000000000006,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.08400000000000006,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.08800000000000006},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.08500000000000006,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.08500000000000006,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.08500000000000006,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.08500000000000006,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.08500000000000006,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.08500000000000006,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.08900000000000007},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.08600000000000006,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.08600000000000006,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.08600000000000006,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.08600000000000006,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.08600000000000006,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.08600000000000006,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.09000000000000007},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.08700000000000006,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.08700000000000006,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.08700000000000006,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.08700000000000006,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.08700000000000006,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.08700000000000006,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.09100000000000007},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.08800000000000006,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.08800000000000006,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.08800000000000006,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.08800000000000006,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.08800000000000006,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.08800000000000006,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.09200000000000007},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.08900000000000007,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.08900000000000007,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.08900000000000007,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.08900000000000007,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.08900000000000007,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.08900000000000007,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.09300000000000007},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.09000000000000007,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.09000000000000007,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.09000000000000007,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.09000000000000007,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.09000000000000007,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.09000000000000007,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.09400000000000007},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.09100000000000007,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.09100000000000007,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.09100000000000007,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.09100000000000007,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.09100000000000007,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.09100000000000007,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.09500000000000007},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.09200000000000007,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.09200000000000007,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.09200000000000007,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.09200000000000007,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.09200000000000007,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.09200000000000007,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.09600000000000007},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.09300000000000007,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.09300000000000007,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.09300000000000007,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.09300000000000007,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.09300000000000007,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.09300000000000007,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.09700000000000007},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.09400000000000007,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.09400000000000007,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.09400000000000007,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.09400000000000007,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.09400000000000007,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.09400000000000007,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.09800000000000007},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.09500000000000007,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.09500000000000007,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.09500000000000007,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.09500000000000007,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.09500000000000007,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.09500000000000007,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.09900000000000007},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.09600000000000007,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.09600000000000007,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.09600000000000007,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.09600000000000007,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.09600000000000007,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.09600000000000007,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.10000000000000007},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.09700000000000007,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.09700000000000007,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.09700000000000007,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.09700000000000007,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.09700000000000007,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.09700000000000007,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.10100000000000008},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.09800000000000007,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.09800000000000007,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.09800000000000007,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.09800000000000007,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.09800000000000007,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.09800000000000007,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.10200000000000008},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.09900000000000007,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.09900000000000007,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.09900000000000007,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.09900000000000007,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.09900000000000007,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.09900000000000007,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.10300000000000008},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.10000000000000007,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.10000000000000007,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.10000000000000007,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.10000000000000007,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.10000000000000007,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.10000000000000007,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.10400000000000008},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.10100000000000008,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.10100000000000008,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.10100000000000008,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.10100000000000008,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.10100000000000008,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.10100000000000008,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.10500000000000008},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.10200000000000008,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.10200000000000008,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.10200000000000008,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.10200000000000008,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.10200000000000008,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.10200000000000008,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.10600000000000008},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.10300000000000008,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.10300000000000008,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.10300000000000008,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.10300000000000008,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.10300000000000008,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.10300000000000008,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.10700000000000008},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.10400000000000008,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.10400000000000008,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.10400000000000008,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.10400000000000008,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.10400000000000008,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.10400000000000008,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.10800000000000008},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.10500000000000008,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.10500000000000008,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.10500000000000008,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.10500000000000008,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.10500000000000008,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.10500000000000008,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.10900000000000008},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.10600000000000008,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.10600000000000008,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.10600000000000008,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.10600000000000008,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.10600000000000008,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.10600000000000008,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.11000000000000008},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.10700000000000008,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.10700000000000008,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.10700000000000008,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.10700000000000008,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.10700000000000008,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.10700000000000008,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.11100000000000008},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.10800000000000008,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.10800000000000008,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.10800000000000008,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.10800000000000008,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.10800000000000008,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.10800000000000008,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.11200000000000009},
#  {'GeneralHospitalBuildingProcess_Maharashtra_india': 0.10900000000000008,
#   'GeneralHospitalBuildingProcess_Delhi_india': 0.10900000000000008,
#   'GeneralHospitalBuildingProcess_Uttar Pradesh_india': 0.10900000000000008,
#   'GeneralHospitalBuildingProcess_Rajasthan_india': 0.10900000000000008,
#   'GeneralHospitalBuildingProcess_Kerala_india': 0.10900000000000008,
#   'GeneralHospitalBuildingProcess_West Bengal_india': 0.10900000000000008,
#   'GeneralHospitalBuildingProcess_Gujarat_india': 0.11300000000000009}]

# %% [markdown]
# #### DIsease Reasearch Center Implementation  (Increases C value)

# %%
ind = gpe.Country(**ind_config)

# %%
# Make increase number of genreal hospitals in each locus mentioned in state list if the country has enough GDP and recovered people in that locus. Also increase the recovery rate "C" based on the number of hospitals in that locus and population density (if more then increase in C is lower)
class DiseaseResearchBuildingProcess(ProcessV1):
    RANK = 1
    DOMAIN = (gpe.Country,)

    def __init__(
        self,
        id: str,
        entities,
        status: str,
        country,
        num_hospitals,
        gdp_cost_per_hospital=5000,
        min_recovered_people=100,
    ):
        super().__init__(id, entities, status)
        self.gdp_cost_per_hospital = gdp_cost_per_hospital
        self.min_recovered_people = min_recovered_people
        self.num_hospitals = num_hospitals
        self.country = country

    def while_dormant(self, step: int):
        pass

    def while_alive(self, step: int):
        for i, country in enumerate(self.country):
                if (
                        self.entities[country].gdp >= self.gdp_cost_per_hospital * self.num_hospitals[i]
                        and locus.recovered >= self.min_recovered_people
                    ):
                        # Deduct the costs from the country's GDP
                        self.entities[country].gdp -= (
                            self.gdp_cost_per_hospital * self.num_hospitals[i]
                        )

                        # Increase the number of hospitals in the locus
                        self.entities[country].disease_research_center += self.num_hospitals[i]
                    else:
                        print("pass1")
                        pass
                if (
                    locus.recovered >= self.min_recovered_people
                    and self.entities[country].disease_research_center > 0
                ):
                    # Reduce the recovery rate "C" based on the number of hospitals
                    if locus.general_hospitals * 0.0005 <= 0.001:
                        locus.C += locus.general_hospitals * 0.005
                    else:
                        locus.C += 0.001

                    # Add a trickle of Healthcare resource stockpile, Sanitation Equipment stockpile and Human Welfare resource
                    self.entities[country].health_resource_stockpile += 0.5
                    self.entities[country].sanitation_equipment_stockpile += 0.5
                    self.entities[country].human_welfare_resource += 0.2

        return {
            "DiseaseResearchBuildingProcess"
            + "_"
            + str(locus.name)
            + "_"
            + str(country): locus.C
            for locus in self.entities[country].loci
        }

    def run(self, step: int):
        if self.status == "ALIVE":
            return self.while_alive(step)

# %%
disease_reseach_process = DiseaseResearchBuildingProcess(
    "DiseaseResearchBuildingProcess",
    {"india": ind},
    "ALIVE",
    country=["india", "india"],
    num_hospitals=[1, 5],
)

k = []
for i in range(100):
    k.append(disease_reseach_process.run(i))
    ind.sync()

k
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[353], line 11
#       9 k = []
#      10 for i in range(100):
# ---> 11     k.append(disease_reseach_process.run(i))
#      12     ind.sync()
#      14 k
#
# Cell In[352], line 69, in DiseaseResearchBuildingProcess.run(self, step)
#      67 def run(self, step: int):
#      68     if self.status == "ALIVE":
# ---> 69         return self.while_alive(step)
#
# File d:\IIT MANDI\KBG Coordinator\MIRAZ\Epidemic_2\NEW_ENGINE\epidemic_engine\Lib\site-packages\pydantic\validate_call_decorator.py:59, in validate_call.<locals>.validate.<locals>.wrapper_function(*args, **kwargs)
#      57 @functools.wraps(function)
#      58 def wrapper_function(*args, **kwargs):
# ---> 59     return validate_call_wrapper(*args, **kwargs)
#
# File d:\IIT MANDI\KBG Coordinator\MIRAZ\Epidemic_2\NEW_ENGINE\epidemic_engine\Lib\site-packages\pydantic\_internal\_validate_call.py:81, in ValidateCallWrapper.__call__(self, *args, **kwargs)
#      80 def __call__(self, *args: Any, **kwargs: Any) -> Any:
# ---> 81     res = self.__pydantic_validator__.validate_python(pydantic_core.ArgsKwargs(args, kwargs))
#      82     if self.__return_pydantic_validator__:
#      83         return self.__return_pydantic_validator__(res)
#
# Cell In[352], line 28, in DiseaseResearchBuildingProcess.while_alive(self, step)
#      26 for i, country in enumerate(self.country):
#      27     for locus in self.entities[country].loci:
# ---> 28         if locus.name == self.state[i]:
#      29             if (
#      30                 self.entities[country].gdp >= self.gdp_cost_per_hospital * self.num_hospitals[i]
#      31                 and locus.recovered >= self.min_recovered_people
#      32             ):
#      33                 # Deduct the costs from the country's GDP
#      34                 self.entities[country].gdp -= (
#      35                     self.gdp_cost_per_hospital * self.num_hospitals[i]
#      36                 )
#
# AttributeError: 'DiseaseResearchBuildingProcess' object has no attribute 'state'

# %%
import math

# %%
ind = gpe.Country(**ind_config)

# %%
# Make a process to build Vaccine Distribution Centers in each locus mentioned in state list if the country has enough GDP, Health Resource stockpile, Sanitation Equipment stockpile. Take a string of vaccine type and locus name as input. If the country with the locus has the vaccine in stock then distribute the vaccine and update the C value of all the loci of teh country based on distance of the locus from the VDC and the effectiveness of the vaccine. Return the updated vaccine stock and C value of all loci over time

class VaccineDistributionCenterBuildingProcess(ProcessV1):
    RANK = 1
    DOMAIN = (gpe.Country,)

    def __init__(
        self,
        id: str,
        entities,
        status: str,
        country,
        state,
        num_centers,
        vaccine_type,
        gdp_cost_per_center=5000,
        health_resource_cost_per_center=500,
        sanitation_equipment_cost_per_center=500,
    ):
        super().__init__(id, entities, status)
        self.gdp_cost_per_center = gdp_cost_per_center
        self.health_resource_cost_per_center = health_resource_cost_per_center
        self.sanitation_equipment_cost_per_center = sanitation_equipment_cost_per_center
        self.vaccine_type = vaccine_type
        self.country = country
        self.num_centers = num_centers
        self.state = state

    def while_dormant(self, step: int):
        pass

    def calculate_proximity(self, lat1, lon1, lat2, lon2):
        # Euclidean distance
        distance = math.sqrt((lat2 - lat1) ** 2 + (lon2 - lon1) ** 2)
        return distance

    def while_alive(self, step: int):
        for i, country in enumerate(self.country):
            for locus in self.entities[country].loci:
                if locus.name == self.state[i]:
                    if (
                        self.entities[country].gdp >= self.gdp_cost_per_center * self.num_centers[i]
                        and self.entities[country].health_resource_stockpile
                        >= self.health_resource_cost_per_center * self.num_centers[i]
                        and self.entities[country].sanitation_equipment_stockpile
                        >= self.sanitation_equipment_cost_per_center * self.num_centers[i]
                    ):
                        # Deduct the costs from the country's resources
                        self.entities[country].gdp -= self.gdp_cost_per_center * self.num_centers[i]
                        self.entities[
                            country
                        ].health_resource_stockpile -= self.health_resource_cost_per_center * self.num_centers[i]
                        self.entities[country].sanitation_equipment_stockpile -= 
                            self.sanitation_equipment_cost_per_center * self.num_centers[i]

                        # Increase the number of vaccine distribution centers in the country
                        for locus in self.entities[country].loci:
                            if locus.name == self.state[i]:
                                locus.vaccine_distribution_centers += self.num_centers[i]

                        # Distribute the vaccines
                        for vaccine in self.entities[country].vaccines_stock:
                            # reduce vaccine quantity by 20% for each VDC
                            if vaccine["name"] == self.vaccine_type and vaccine["quantity"] > 0:
                                vaccine["quantity"] -= vaccine["quantity"]*0.2

                        # Create a dictionary of latitudes and longitudes to the number of VDCs
                        lat_lon_to_vdc = {
                            (locus.lat, locus.lon): locus.vaccine_distribution_centers
                            for locus in self.entities[country].loci
                        }

                        # Calculate the effect of the VDCs on each locus and update the C value
                        for locus in self.entities[country].loci:
                            for (lat, lon), vdc in lat_lon_to_vdc.items():
                                distance = self.calculate_proximity(locus.lat, locus.lon, lat, lon)
                                print(self.entities[country].vaccines_stock)
                                if distance == 0:

                                    for vaccine in self.entities[country].vaccines_stock:

                                        if vaccine["name"] == self.vaccine_type:
                                            if locus.C - locus.C * vdc * vaccine["effectiveness"] <= 0.3:
                                                locus.C += locus.C * vdc * vaccine["effectiveness"]
                                            locus.C -= locus.C * vdc * vaccine["effectiveness"]
                                else:
                                    for vaccine in self.entities[country].vaccines_stock:
                                        if vaccine["name"] == self.vaccine_type:
                                            locus.C -= locus.C * vdc * vaccine["effectiveness"] / distance

        # Return a dictionary with the change in C for all loci over time and the qantities of all vannine types
        # C_change_over_time = {locus.name: locus.C for locus in self.entities[country].loci}
        # return  C_change_over_time

        return {
            "VaccineDistributionCenterBuildingProcess"
            + "_"
            + str(locus.name)
            + "_"
            + str(country): locus.C

            for locus in self.entities[country].loci
        }
        # Return in the above format   

    def run(self, step: int):
        if self.status == "ALIVE":
            return self.while_alive(step)
# Out:
#   Cell In[375], line 53
#     self.entities[country].sanitation_equipment_stockpile -=
#                                                              ^
# SyntaxError: invalid syntax

# %%
vaccine_distribution_center_building_process = VaccineDistributionCenterBuildingProcess(
    "VaccineDistributionCenterBuildingProcess",
    {"india": ind},
    "ALIVE",
    country=["india", "india"],
    state=["Delhi", "Gujarat"],
    num_centers=[1, 5],
    vaccine_type="ABC",
)

k = []
for i in range(100):
    k.append(vaccine_distribution_center_building_process.run(i))
    ind.sync()

k
# Out:
# [{'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01},
#  {'VaccineDistributionCenterBuildingProcess_Maharashtra_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Delhi_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Uttar Pradesh_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Rajasthan_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Kerala_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_West Bengal_india': 0.01,
#   'VaccineDistributionCenterBuildingProcess_Gujarat_india': 0.01}]

# %% [markdown]
# ### **DS Parameter**

# %% [markdown]
# Changes value of Susceptable and move to Dead

# %%
# Make a process to increase Ds value in each of loci of all countries in entities with similar class structure as above


class IncreaseDsProcess(ProcessV1):
    RANK = 1
    DOMAIN = (gpe.Country,)

    def __init__(self, id: str, entities, status: str):
        super().__init__(id, entities, status)

    def while_dormant(self, step: int):
        pass

    def scale_Ds_value(self, input_value, susceptible_percent):
        # Scale the input value from the input range to the output range
        scaled_value = (input_value * susceptible_percent - 0) / (
            max_living_population - min_living_population
        ) * (5e-3 - 5e-5) + 5e-5
        return scaled_value

    def while_alive(self, step: int):
        for country in self.entities:
            for locus in country.loci:
                print(locus.name)
                print(locus.Ds, "Start")
                if locus.susceptible > 0 and locus.Ds < 0.2 and locus.Ds > 0:
                    # Calculate the percentage of susceptible people in the locus
                    susceptible_percent = locus.susceptible / (
                        locus.susceptible + locus.infected + locus.recovered
                    )

                    # Calculate scale based on country attributes and susceptible percent
                    scale = self.scale_Ds_value(
                        base_death_rate
                        * (1 - (min_gdp / country.gdp))
                        * country.happiness_index
                        * country.human_welfare_resource,
                        susceptible_percent,
                    )
                    if locus.Ds + scale <= 0.2:
                        locus.Ds += scale
                    else:
                        locus.Ds = 0.2

                    if locus.susceptible > 0:
                        percent_to_move = locus.Ds * locus.susceptible
                        locus.infected += percent_to_move
                        locus.susceptible -= percent_to_move
                    else:
                        locus.susceptible = 0

                print(locus.Ds, "End")

        return {
            "IncreaseBProcess"
            + "_"
            + str(locus.name)
            + "_"
            + str(country): [
                locus.susceptible,
                locus.infected,
                locus.recovered,
                locus.dead,
            ]
            for locus in self.entities[country].loci
        }

    def run(self):
        if self.status == "ALIVE":
            return self.while_active()
